# %% [markdown]
# # Data Collection and Exploratory Data Analysis

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Stef0916/chemoinformatics-bioinformatics/blob/main/acetylcholinesterase-QSAR/notebooks/1-Getting-bioactivity-data.ipynb)

# %% [markdown]
# ## 1. Load Libraries

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## 2. Search for Target Protein

# %%
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3              Bemisia tabaci
# 4   Leptinotarsa decemlineata
# 5         Torpedo californica
# 6                Mus musculus
# 7           Rattus norvegicus
# 8    Electrophorus electricus
# 9                  Bos taurus
# 10          Anopheles gambiae
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16          Rattus norvegicus
# 17        Plutella xylostella
# 18            Musca domestica
# 19  Pediculus humanus capitis
# 20          Spodoptera litura
# 21      Laodelphax striatella
# 22        Schizaphis graminum
# 23     Caenorhabditis elegans
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   27.0
# 1                        Cholinesterases; ACHE & BCHE   27.0
# 2                                Acetylcholinesterase   18.0
# 3                                               AChE2   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                Acetylcholinesterase   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                               Acetylcholinesterase   14.0
# 23                             Acetylcholinesterase 1   14.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False    CHEMBL2366409
# 4                False    CHEMBL2366490
# 5                False       CHEMBL4780
# 6                False       CHEMBL3198
# 7                False       CHEMBL3199
# 8                False       CHEMBL4078
# 9                False       CHEMBL4768
# 10               False    CHEMBL2046266
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2111475
# 17               False    CHEMBL2242729
# 18               False    CHEMBL2242743
# 19               False    CHEMBL2362988
# 20               False    CHEMBL2366422
# 21               False    CHEMBL2366446
# 22               False    CHEMBL2366511
# 23               False    CHEMBL3341583
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 17  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7038
# 4     7539
# 5     7787
# 6    10090
# 7    10116
# 8     8005
# 9     9913
# 10    7165
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   10116
# 17   51655
# 18    7370
# 19  121226
# 20   69820
# 21  195883
# 22   13262
# 23    6239

# %% [markdown]
# ## 3. Filter “Homo Sapiens” targets

# %%
target_hs = targets.loc[targets['organism'] == 'Homo sapiens']
target_hs.sort_values(by='score', ascending=False)
# Out:
#                                     cross_references      organism  \
# 0  [{'xref_id': 'P22303', 'xref_name': None, 'xre...  Homo sapiens
# 1                                                 []  Homo sapiens
#
#                       pref_name  score  species_group_flag target_chembl_id  \
# 0          Acetylcholinesterase   27.0               False        CHEMBL220
# 1  Cholinesterases; ACHE & BCHE   27.0               False    CHEMBL2095233
#
#                                    target_components        target_type  \
# 0  [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
#
#    tax_id
# 0    9606
# 1    9606

# %% [markdown]
# ## 4. Select target

# %%
selected_target = target_hs.target_chembl_id.iloc[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# ## 5. Retrieve Bioactivity Data with IC50 as a filter

# %%
activity = new_client.activity
bioactivities = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")
print(bioactivities)
# Out:
# [{'action_type': None, 'activity_comment': None, 'activity_id': 33969, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL643384', 'assay_description': 'Inhibitory concentration against acetylcholinesterase', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1148382', 'document_journal': 'J Med Chem', 'document_year': 2004, 'ligand_efficiency': {'bei': '19.61', 'le': '0.36', 'lle': '3.32', 'sei': '9.21'}, 'molecule_chembl_id': 'CHEMBL133897', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL133897', 'pchembl_value': '6.12', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 252547, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '750.0', 'target_chembl_id': 'CHEMBL220', 'target_organism': 'Homo sapiens', 'target_pref_name': 'Acetylcholinesterase', 'target_tax_id': '9606', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '0.75'}, {'action_type': None, 'activity_comment': None, 'activity_id': 37563, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL643384', 'assay_description': 'Inhibitory concentration against acetylcholinesterase', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1148382', 'document_journal': 'J Med Chem', 'document_year': 2004, 'ligand_efficiency': {'bei': '18.57', 'le': '0.38', 'lle': '2.45', 'sei': '13.72'}, 'molecule_chembl_id': 'CHEMBL336398', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL336398', 'pchembl_value': '7.00', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 252533, 'relation': '=', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '=', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '100.0', 'target_chembl_id': 'CHEMBL220', 'target_organism': 'Homo sapiens', 'target_pref_name': 'Acetylcholinesterase', 'target_tax_id': '9606', 'text_value': None, 'toid': None, 'type': 'IC50', 'units': 'uM', 'uo_units': 'UO_0000065', 'upper_value': None, 'value': '0.1'}, {'action_type': None, 'activity_comment': None, 'activity_id': 37565, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL643384', 'assay_description': 'Inhibitory concentration against acetylcholinesterase', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1148382', 'document_journal': 'J Med Chem', 'document_year': 2004, 'ligand_efficiency': None, 'molecule_chembl_id': 'CHEMBL131588', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL131588', 'pchembl_value': None, 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 252530, 'relation': '>', 'src_id': 1, 'standard_flag': 1, 'standard_relation': '>', 'standard_text_value': None, 'standard_type': 'IC50', 'standard_units': 'nM', 'standard_upper_value': None, 'standard_value': '50000.0', 'target_chembl_id': 'CHEMBL220', 'target_organism': ...

# %%
bioactivity_df = pd.DataFrame.from_dict(bioactivities)

# %%
bioactivity_df.shape
# Out:
# (8832, 46)

# %%
bioactivity_df.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33969                  []
# 1        None             None        37563                  []
# 2        None             None        37565                  []
# 3        None             None        38902                  []
# 4        None             None        41170                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 1    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 2    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 3    CHEMBL643384  Inhibitory concentration against acetylcholine...
# 4    CHEMBL643384  Inhibitory concentration against acetylcholine...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism      target_pref_name target_tax_id text_value  toid  type  \
# 0    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 1    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 2    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 3    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
# 4    Homo sapiens  Acetylcholinesterase          9606       None  None  IC50
#
#   units    uo_units upper_value value
# 0    uM  UO_0000065        None  0.75
# 1    uM  UO_0000065        None   0.1
# 2    uM  UO_0000065        None  50.0
# 3    uM  UO_0000065        None   0.3
# 4    uM  UO_0000065        None   0.8
#
# [5 rows x 46 columns]

# %%
bioactivity_df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
data = bioactivity_df[['canonical_smiles', 'molecule_chembl_id',
                       'standard_type', 'standard_units', 'standard_value']]

# %%
data
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0                 CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1       CHEMBL133897
# 1            O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1       CHEMBL336398
# 2     CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1       CHEMBL131588
# 3         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F       CHEMBL130628
# 4             CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C       CHEMBL130478
# ...                                                 ...                ...
# 8827      CC[C@@]1(c2cccc(OC(=O)Nc3ccccc3)c2)CCCCN(C)C1      CHEMBL5219046
# 8828             O=c1[nH]c2ccc(OCc3ccc(F)cc3)cc2c(=O)o1      CHEMBL5219594
# 8829         CC(C)c1ccc(COc2ccc3[nH]c(=O)oc(=O)c3c2)cc1      CHEMBL5219958
# 8830                            Nc1c2c(nc3ccccc13)CCCC2           CHEMBL95
# 8831  Cn1ccc2cc(-c3cnc4ccc(C(=O)N5CCCCC5)cc4n3)ccc2c1=O      CHEMBL5220884
#
#      standard_type standard_units standard_value
# 0             IC50             nM          750.0
# 1             IC50             nM          100.0
# 2             IC50             nM        50000.0
# 3             IC50             nM          300.0
# 4             IC50             nM          800.0
# ...            ...            ...            ...
# 8827          IC50             nM          274.0
# 8828          IC50             nM        76200.0
# 8829          IC50             nM        55000.0
# 8830          IC50             nM         1180.0
# 8831          IC50             nM         5400.0
#
# [8832 rows x 5 columns]

# %% [markdown]
# ## 6. Exploratory Data Analysis

# %% [markdown]
# ### 6.1 Drop Nan SMILES

# %%
len(data.loc[data['canonical_smiles'].isnull()])
# Out:
# 35

# %%
data.loc[data['canonical_smiles'].isnull()]
# Out:
#      canonical_smiles molecule_chembl_id standard_type standard_units  \
# 1911             None      CHEMBL2448138          IC50             nM
# 2028             None      CHEMBL2021458          IC50           None
# 2032             None      CHEMBL2021459          IC50             nM
# 3133             None         CHEMBL1366          IC50           None
# 3152             None      CHEMBL1476898          IC50           None
# 3164             None      CHEMBL1458880          IC50           None
# 3320             None       CHEMBL306043          IC50           None
# 3336             None      CHEMBL1201469          IC50           None
# 3351             None      CHEMBL1200431          IC50           None
# 3381             None      CHEMBL1909056          IC50           None
# 3421             None        CHEMBL11359          IC50           None
# 3442             None         CHEMBL1351          IC50           None
# 3447             None      CHEMBL1909057          IC50           None
# 3459             None      CHEMBL1909054          IC50           None
# 3495             None      CHEMBL1909055          IC50           None
# 3501             None      CHEMBL1200528          IC50           None
# 3541             None      CHEMBL1909075          IC50           None
# 3543             None       CHEMBL414804          IC50           None
# 3597             None      CHEMBL3559671          IC50           None
# 3613             None      CHEMBL2108139          IC50           None
# 3639             None      CHEMBL1909071          IC50           None
# 3656             None      CHEMBL1909064          IC50           None
# 3658             None      CHEMBL1909067          IC50           None
# 3674             None      CHEMBL1909068          IC50           None
# 3687             None      CHEMBL1909062          IC50           None
# 3691             None      CHEMBL1909069          IC50           None
# 3704             None      CHEMBL1909063          IC50           None
# 3732             None      CHEMBL1201631          IC50           None
# 3738             None      CHEMBL1200693          IC50           None
# 3796             None         CHEMBL1386          IC50           None
# 3809             None      CHEMBL1909083          IC50           None
# 3828             None      CHEMBL1909079          IC50           None
# 3836             None       CHEMBL136478          IC50           None
# 3853             None       CHEMBL179166          IC50           None
# 3905             None       CHEMBL508338          IC50           None
#
#      standard_value
# 1911           4.04
# 2028           None
# 2032       200000.0
# 3133           None
# 3152           None
# 3164           None
# 3320           None
# 3336           None
# 3351           None
# 3381           None
# 3421           None
# 3442           None
# 3447           None
# 3459           None
# 3495           None
# 3501           None
# 3541           None
# 3543           None
# 3597           None
# 3613           None
# 3639           None
# 3656           None
# 3658           None
# 3674           None
# 3687           None
# 3691           None
# 3704           None
# 3732           None
# 3738           None
# 3796           None
# 3809           None
# 3828           None
# 3836           None
# 3853           None
# 3905           None

# %%
data = data.loc[~data['canonical_smiles'].isnull()]
data.shape
# Out:
# (8797, 5)

# %%
data.loc[data['canonical_smiles'].isnull()]
# Out:
# Empty DataFrame
# Columns: [canonical_smiles, molecule_chembl_id, standard_type, standard_units, standard_value]
# Index: []

# %% [markdown]
# ### 6.2 Drop Nan standard_value

# %%
len(data.loc[data['standard_value'].isnull()])
# Out:
# 1250

# %%
data = data.loc[~data['standard_value'].isnull()]
data.shape
# Out:
# (7547, 5)

# %% [markdown]
# ## 6.3 Manage Standard Values

# %%
data['standard_units'].unique()
# Out:
# array(['nM', 'ug.mL-1', "10'3pM", "10'6pM", "10'5pM", '10^-4microM', 'µM'],
#       dtype=object)

# %%
non_nM = data.loc[data['standard_units'] != 'nM']

# %%
len(non_nM)
# Out:
# 48

# %%
non_nM['standard_units'].value_counts()
# Out:
# ug.mL-1        38
# 10'5pM          3
# 10'6pM          2
# 10^-4microM     2
# µM              2
# 10'3pM          1
# Name: standard_units, dtype: int64

# %%
data = data.loc[data['standard_units'] == 'nM']
data.shape
# Out:
# (7499, 5)

# %% [markdown]
# ## 6.4 Check for duplicates

# %%
duplicates = data['molecule_chembl_id'].value_counts()
duplicates
# Out:
# CHEMBL95         171
# CHEMBL502        135
# CHEMBL659         73
# CHEMBL94          51
# CHEMBL636         47
#                 ...
# CHEMBL1773490      1
# CHEMBL1773489      1
# CHEMBL1773488      1
# CHEMBL1773487      1
# CHEMBL5220884      1
# Name: molecule_chembl_id, Length: 6125, dtype: int64

# %% [markdown]
# Now, I'll sort the data by standard value. The lowest the value, the strongest the activity. This will allow me to use the duplicated() function to drop the less active compounds. The duplicated function only shows from the second occurency of the duplicated values, and leaves outside the first occurrence. With the sorted data, I ensure that only the most potent compound will stay in the dataframe.

# %%
data_sorted = data.sort_values(by='standard_value', ascending=True)
data_sorted.head()
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 7994  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...      CHEMBL4780352
# 7166  O=C(CCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2...       CHEMBL199670
# 7183  O=C(CCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2c...       CHEMBL370807
# 7182  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5cc(Cl)c...       CHEMBL372202
# 7181  COc1ccc2[nH]cc(CCNC(=O)CCCCCNc3c4c(nc5cc(Cl)cc...      CHEMBL4468781
#
#      standard_type standard_units standard_value
# 7994          IC50             nM            0.0
# 7166          IC50             nM       0.000005
# 7183          IC50             nM       0.000005
# 7182          IC50             nM       0.000005
# 7181          IC50             nM       0.000005

# %%
data_sorted.loc[data_sorted['molecule_chembl_id'].duplicated()]
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 1818  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
# 1436  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
# 1434  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5cc(Cl)c...       CHEMBL372202
# 1830  O=C(CCc1c[nH]c2ccccc12)NCCCCCCCNc1c2c(nc3cc(Cl...       CHEMBL225198
# 1622  O=C(CCc1c[nH]c2ccccc12)NCCCCCCNc1c2c(nc3cc(Cl)...       CHEMBL225567
# ...                                                 ...                ...
# 8748                            Nc1c2c(nc3ccccc13)CCCC2           CHEMBL95
# 648                c1ccc(CN2CCC(CCc3nsc4ccccc34)CC2)cc1       CHEMBL328102
# 8218    COc1cccc(N2CCN(C(=O)/C=C/c3ccc(O)c(OC)c3)CC2)c1      CHEMBL4785400
# 8199                CCN(C)C(=O)Oc1cccc([C@H](C)N(C)C)c1          CHEMBL636
# 7959                           C[n+]1ccccc1/C=N/O.[Cl-]          CHEMBL748
#
#      standard_type standard_units standard_value
# 1818          IC50             nM          0.008
# 1436          IC50             nM          0.008
# 1434          IC50             nM           0.04
# 1830          IC50             nM           0.06
# 1622          IC50             nM           0.07
# ...            ...            ...            ...
# 8748          IC50             nM           99.0
# 648           IC50             nM           99.0
# 8218          IC50             nM         9910.0
# 8199          IC50             nM         9940.0
# 7959          IC50             nM       996000.0
#
# [1374 rows x 5 columns]

# %%
data.loc[data['molecule_chembl_id'] == 'CHEMBL199585']
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 1436  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
# 1818  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
# 7172  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
#
#      standard_type standard_units standard_value
# 1436          IC50             nM          0.008
# 1818          IC50             nM          0.008
# 7172          IC50             nM       0.000005

# %%
data_sorted = data_sorted.loc[~data_sorted['molecule_chembl_id'].duplicated()]

# %%
data_sorted
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 7994  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...      CHEMBL4780352
# 7166  O=C(CCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2...       CHEMBL199670
# 7183  O=C(CCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2c...       CHEMBL370807
# 7182  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5cc(Cl)c...       CHEMBL372202
# 7181  COc1ccc2[nH]cc(CCNC(=O)CCCCCNc3c4c(nc5cc(Cl)cc...      CHEMBL4468781
# ...                                                 ...                ...
# 6318                              C[n+]1ccccc1C=NO.[I-]        CHEMBL14577
# 5151         CN(CCCCCCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1.Cl      CHEMBL3402709
# 6565       O=C(NCCCCCCNCc1ccc2ccccc2c1)c1cc(Cl)nc(Cl)c1      CHEMBL4163781
# 5315  COc1ccc(C(=O)O[C@H]2CC[C@@]3(C)[C@@H](CC[C@@]4...      CHEMBL3586198
# 6900                  O=C1/C(=C/c2ccc(O)cc2)COc2ccccc21      CHEMBL1383041
#
#      standard_type standard_units standard_value
# 7994          IC50             nM            0.0
# 7166          IC50             nM       0.000005
# 7183          IC50             nM       0.000005
# 7182          IC50             nM       0.000005
# 7181          IC50             nM       0.000005
# ...            ...            ...            ...
# 6318          IC50             nM       995700.0
# 5151          IC50             nM          997.0
# 6565          IC50             nM        99700.0
# 5315          IC50             nM         9980.0
# 6900          IC50             nM        99900.0
#
# [6125 rows x 5 columns]

# %%
data_sorted.reset_index()
# Out:
#       index                                   canonical_smiles  \
# 0      7994  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...
# 1      7166  O=C(CCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2...
# 2      7183  O=C(CCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2c...
# 3      7182  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5cc(Cl)c...
# 4      7181  COc1ccc2[nH]cc(CCNC(=O)CCCCCNc3c4c(nc5cc(Cl)cc...
# ...     ...                                                ...
# 6120   6318                              C[n+]1ccccc1C=NO.[I-]
# 6121   5151         CN(CCCCCCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1.Cl
# 6122   6565       O=C(NCCCCCCNCc1ccc2ccccc2c1)c1cc(Cl)nc(Cl)c1
# 6123   5315  COc1ccc(C(=O)O[C@H]2CC[C@@]3(C)[C@@H](CC[C@@]4...
# 6124   6900                  O=C1/C(=C/c2ccc(O)cc2)COc2ccccc21
#
#      molecule_chembl_id standard_type standard_units standard_value
# 0         CHEMBL4780352          IC50             nM            0.0
# 1          CHEMBL199670          IC50             nM       0.000005
# 2          CHEMBL370807          IC50             nM       0.000005
# 3          CHEMBL372202          IC50             nM       0.000005
# 4         CHEMBL4468781          IC50             nM       0.000005
# ...                 ...           ...            ...            ...
# 6120        CHEMBL14577          IC50             nM       995700.0
# 6121      CHEMBL3402709          IC50             nM          997.0
# 6122      CHEMBL4163781          IC50             nM        99700.0
# 6123      CHEMBL3586198          IC50             nM         9980.0
# 6124      CHEMBL1383041          IC50             nM        99900.0
#
# [6125 rows x 6 columns]

# %%
data_sorted
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 7994  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...      CHEMBL4780352
# 7166  O=C(CCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2...       CHEMBL199670
# 7183  O=C(CCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2c...       CHEMBL370807
# 7182  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5cc(Cl)c...       CHEMBL372202
# 7181  COc1ccc2[nH]cc(CCNC(=O)CCCCCNc3c4c(nc5cc(Cl)cc...      CHEMBL4468781
# ...                                                 ...                ...
# 6318                              C[n+]1ccccc1C=NO.[I-]        CHEMBL14577
# 5151         CN(CCCCCCCN1C(=O)c2ccccc2C1=O)Cc1ccccc1.Cl      CHEMBL3402709
# 6565       O=C(NCCCCCCNCc1ccc2ccccc2c1)c1cc(Cl)nc(Cl)c1      CHEMBL4163781
# 5315  COc1ccc(C(=O)O[C@H]2CC[C@@]3(C)[C@@H](CC[C@@]4...      CHEMBL3586198
# 6900                  O=C1/C(=C/c2ccc(O)cc2)COc2ccccc21      CHEMBL1383041
#
#      standard_type standard_units standard_value
# 7994          IC50             nM            0.0
# 7166          IC50             nM       0.000005
# 7183          IC50             nM       0.000005
# 7182          IC50             nM       0.000005
# 7181          IC50             nM       0.000005
# ...            ...            ...            ...
# 6318          IC50             nM       995700.0
# 5151          IC50             nM          997.0
# 6565          IC50             nM        99700.0
# 5315          IC50             nM         9980.0
# 6900          IC50             nM        99900.0
#
# [6125 rows x 5 columns]

# %%
 # Randomize the sorted DataFrame
data_clean = data_sorted.sample(frac=1).reset_index(drop=True)

# %%
data_clean
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# ...                                                 ...                ...
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6121  CCN(C)C(=O)Oc1ccc(-c2cc(=O)c3c(OC(=O)N(C)CC)cc...      CHEMBL4787451
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#      standard_type standard_units standard_value
# 0             IC50             nM           18.2
# 1             IC50             nM           0.41
# 2             IC50             nM           80.0
# 3             IC50             nM      1020000.0
# 4             IC50             nM          178.0
# ...            ...            ...            ...
# 6120          IC50             nM         1700.0
# 6121          IC50             nM        12300.0
# 6122          IC50             nM          518.0
# 6123          IC50             nM       100000.0
# 6124          IC50             nM           82.0
#
# [6125 rows x 5 columns]

# %% [markdown]
# ## 7. Label: Active, Inactive, Intermediate

# %%
data_clean['standard_value'].dtypes
# Out:
# dtype('O')

# %%
data_clean['standard_value'] = data_clean['standard_value'].astype('float64')

# %%
data_clean['standard_value'].dtypes
# Out:
# dtype('float64')

# %%
bio_class = []

for i in data_clean['standard_value']:
    if i <= 10000:
        bio_class.append('active')
    elif 10000 < i < 20000:
        bio_class.append('intermediate')
    else:
        bio_class.append('inactive')

# %%
data_clean['class'] = bio_class

# %%
data_clean
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# ...                                                 ...                ...
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6121  CCN(C)C(=O)Oc1ccc(-c2cc(=O)c3c(OC(=O)N(C)CC)cc...      CHEMBL4787451
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#      standard_type standard_units  standard_value         class
# 0             IC50             nM           18.20        active
# 1             IC50             nM            0.41        active
# 2             IC50             nM           80.00        active
# 3             IC50             nM      1020000.00      inactive
# 4             IC50             nM          178.00        active
# ...            ...            ...             ...           ...
# 6120          IC50             nM         1700.00        active
# 6121          IC50             nM        12300.00  intermediate
# 6122          IC50             nM          518.00        active
# 6123          IC50             nM       100000.00      inactive
# 6124          IC50             nM           82.00        active
#
# [6125 rows x 6 columns]

# %%
data_clean.loc[data_clean['class'] == 'active']
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# 5     COc1cc2c(cc1OC)C(=O)C(Cc1cc[n+](Cc3cccc(Cl)c3)...      CHEMBL4102333
# ...                                                 ...                ...
# 6118  CCN(CC)CCCCCCCOc1ccc2c(c1)C(=O)/C(=C/c1ccc(CN(...       CHEMBL598824
# 6119  O=C(CCCNc1c2c(nc3ccccc13)CCCC2)CCCNc1c2c(nc3cc...       CHEMBL238230
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#      standard_type standard_units  standard_value   class
# 0             IC50             nM           18.20  active
# 1             IC50             nM            0.41  active
# 2             IC50             nM           80.00  active
# 4             IC50             nM          178.00  active
# 5             IC50             nM            3.27  active
# ...            ...            ...             ...     ...
# 6118          IC50             nM          510.00  active
# 6119          IC50             nM            1.83  active
# 6120          IC50             nM         1700.00  active
# 6122          IC50             nM          518.00  active
# 6124          IC50             nM           82.00  active
#
# [4316 rows x 6 columns]

# %%
data_clean.loc[data_clean['class'] == 'inactive']
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 11               CCN(CC)CCS/C(=N\O)C(=O)c1ccc(Cl)cc1.Cl       CHEMBL544022
# 12          OCCN1CCN(c2nccc(NC(c3ccccc3)c3ccccc3)n2)CC1      CHEMBL1834078
# 14    CO[C@@H]1C=C[C@@]23c4cc5c(cc4CN(CCc4ccccc4)[C@...      CHEMBL4159837
# 26                   CC1(C)Oc2cc3oc(=O)ccc3cc2C[C@@H]1O       CHEMBL481657
# ...                                                 ...                ...
# 6107             COc1ccc2c(c1O)CN1CCc3cc4c(cc3C1C2)OCO4      CHEMBL2314746
# 6108  O=C(CN1CCN(C(=O)c2ccc(Cl)cc2)CC1)N1CCN(CCCc2c[...      CHEMBL4796328
# 6111                CCN(CC)CCS/C(=N\O)c1nc(C(C)(C)C)no1        CHEMBL65891
# 6112      COc1ccc2c3c1O[C@H]1C[C@H](O)CC[C@@]31CCN(C)C2      CHEMBL4167958
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
#
#      standard_type standard_units  standard_value     class
# 3             IC50             nM       1020000.0  inactive
# 11            IC50             nM        520000.0  inactive
# 12            IC50             nM         21600.0  inactive
# 14            IC50             nM        200000.0  inactive
# 26            IC50             nM         28000.0  inactive
# ...            ...            ...             ...       ...
# 6107          IC50             nM        100000.0  inactive
# 6108          IC50             nM         22300.0  inactive
# 6111          IC50             nM        390000.0  inactive
# 6112          IC50             nM         57900.0  inactive
# 6123          IC50             nM        100000.0  inactive
#
# [1418 rows x 6 columns]

# %%
data_clean.loc[data_clean['class'] == 'intermediate']
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 6                O=C(Nc1ccccc1)OC1CCN(C2Cc3ccccc3C2)CC1      CHEMBL4799709
# 13                      c1ccc(-c2ccc(NCN3CCCCC3)nc2)cc1      CHEMBL1084542
# 43       COc1cccc(CN(C)CCOc2ccc3c(c2)oc(=O)c2ccccc23)c1      CHEMBL3335057
# 107   COc1cccc(CN2CCN(CCOc3ccc4c(c3)oc(=O)c3ccccc34)...      CHEMBL3335061
# 132               CN(CCCCNc1ccc(-c2ccccc2)nn1)Cc1ccccc1      CHEMBL1084257
# ...                                                 ...                ...
# 6065    COc1ccc2[nH]cc(CCNC(=O)C3CCN(Cc4ccccc4)CC3)c2c1      CHEMBL3824362
# 6073  CCN(C)C(=O)Oc1ccc(/C=C/C(=O)N2CCN(Cc3ccccc3)CC...      CHEMBL4750360
# 6084  CC(C)=CCC[C@]1(C)[C@@H](CC=C(C)C)C[C@@]2(CC=C(...      CHEMBL4126674
# 6088  COc1cc(/C=C/C(=O)Nc2ccccc2)ccc1OCCCCCCCCCCN1CC...      CHEMBL4074258
# 6121  CCN(C)C(=O)Oc1ccc(-c2cc(=O)c3c(OC(=O)N(C)CC)cc...      CHEMBL4787451
#
#      standard_type standard_units  standard_value         class
# 6             IC50             nM         19200.0  intermediate
# 13            IC50             nM         13000.0  intermediate
# 43            IC50             nM         18400.0  intermediate
# 107           IC50             nM         11400.0  intermediate
# 132           IC50             nM         11000.0  intermediate
# ...            ...            ...             ...           ...
# 6065          IC50             nM         12220.0  intermediate
# 6073          IC50             nM         14800.0  intermediate
# 6084          IC50             nM         18550.0  intermediate
# 6088          IC50             nM         11110.0  intermediate
# 6121          IC50             nM         12300.0  intermediate
#
# [391 rows x 6 columns]

# %%
data_class_active_inactive = data_clean.loc[(data_clean['class'] == 'active') | (data_clean['class'] == 'inactive')]

# %%
data_class_active_inactive
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# ...                                                 ...                ...
# 6119  O=C(CCCNc1c2c(nc3ccccc13)CCCC2)CCCNc1c2c(nc3cc...       CHEMBL238230
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#      standard_type standard_units  standard_value     class
# 0             IC50             nM           18.20    active
# 1             IC50             nM            0.41    active
# 2             IC50             nM           80.00    active
# 3             IC50             nM      1020000.00  inactive
# 4             IC50             nM          178.00    active
# ...            ...            ...             ...       ...
# 6119          IC50             nM            1.83    active
# 6120          IC50             nM         1700.00    active
# 6122          IC50             nM          518.00    active
# 6123          IC50             nM       100000.00  inactive
# 6124          IC50             nM           82.00    active
#
# [5734 rows x 6 columns]

# %%
data_class_active_inactive = data_class_active_inactive.copy()
data_class_active_inactive['Label'] = data_class_active_inactive['class'].apply(lambda x: 1 if x == 'active' else 0)

# %%
data_class_active_inactive
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# ...                                                 ...                ...
# 6119  O=C(CCCNc1c2c(nc3ccccc13)CCCC2)CCCNc1c2c(nc3cc...       CHEMBL238230
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#      standard_type standard_units  standard_value     class  Label
# 0             IC50             nM           18.20    active      1
# 1             IC50             nM            0.41    active      1
# 2             IC50             nM           80.00    active      1
# 3             IC50             nM      1020000.00  inactive      0
# 4             IC50             nM          178.00    active      1
# ...            ...            ...             ...       ...    ...
# 6119          IC50             nM            1.83    active      1
# 6120          IC50             nM         1700.00    active      1
# 6122          IC50             nM          518.00    active      1
# 6123          IC50             nM       100000.00  inactive      0
# 6124          IC50             nM           82.00    active      1
#
# [5734 rows x 7 columns]

# %% [markdown]
# ## 8. IC50 to pIC50

# %%
data_class_active_inactive.sort_values(by='standard_value', ascending=True)
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 4151  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...      CHEMBL4780352
# 5650  O=C(CCCCCCNc1c2c(nc3cc(Cl)ccc13)CCCC2)NCCc1c[n...       CHEMBL381499
# 3250  O=C(CCCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c...      CHEMBL4556734
# 3253  O=C(CCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCCc...       CHEMBL199585
# 5686  COc1ccc2[nH]cc(CCNC(=O)CCCCCNc3c4c(nc5ccccc35)...       CHEMBL199454
# ...                                                 ...                ...
# 699                        CCSC(=O)OCC[N+](C)(C)C.[Cl-]       CHEMBL102637
# 3024              C[N+]1(C)CCO[C@@](O)(c2ccc(C#N)cc2)C1       CHEMBL334938
# 420   COC(=O)C1=C(Nc2ccc(F)cc2)C[C@@H](c2ccccc2)N(c2...      CHEMBL3597055
# 4468            O=C(NP(=O)(NN1CCOCC1)NN1CCOCC1)c1ccccc1      CHEMBL1276534
# 5037  CN(CCCCCCCOc1ccc2c(c1)O/C(=C\c1cccc3ccccc13)C2...       CHEMBL371798
#
#      standard_type standard_units  standard_value     class  Label
# 4151          IC50             nM    0.000000e+00    active      1
# 5650          IC50             nM    5.000000e-06    active      1
# 3250          IC50             nM    5.000000e-06    active      1
# 3253          IC50             nM    5.000000e-06    active      1
# 5686          IC50             nM    5.000000e-06    active      1
# ...            ...            ...             ...       ...    ...
# 699           IC50             nM    1.000000e+07  inactive      0
# 3024          IC50             nM    1.158777e+07  inactive      0
# 420           IC50             nM    1.512000e+07  inactive      0
# 4468          IC50             nM    1.862000e+07  inactive      0
# 5037          IC50             nM    4.960000e+07  inactive      0
#
# [5734 rows x 7 columns]

# %%
data_class_active_inactive.loc[data_class_active_inactive['standard_value'] == 0]
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 4151  COc1cc2c(cc1OC)C(=O)/C(=C/c1ccc(OCCCCN[N+]3(C)...      CHEMBL4780352
#
#      standard_type standard_units  standard_value   class  Label
# 4151          IC50             nM             0.0  active      1

# %%
# Replace 0 with a small value to avoid log(0)
data_class_active_inactive['standard_value'] = data_class_active_inactive['standard_value'].replace(0,5.000000e-06)

# %%
pIC50 = []

for value in data_class_active_inactive['standard_value']:
    molar = value*(1**-9)
    pIC50.append(-np.log10(molar))

# %%
data_class_active_inactive['pIC50'] = pIC50

# %%
data_class_active_inactive.sort_values(by='pIC50', ascending=True)
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 5037  CN(CCCCCCCOc1ccc2c(c1)O/C(=C\c1cccc3ccccc13)C2...       CHEMBL371798
# 4468            O=C(NP(=O)(NN1CCOCC1)NN1CCOCC1)c1ccccc1      CHEMBL1276534
# 420   COC(=O)C1=C(Nc2ccc(F)cc2)C[C@@H](c2ccccc2)N(c2...      CHEMBL3597055
# 3024              C[N+]1(C)CCO[C@@](O)(c2ccc(C#N)cc2)C1       CHEMBL334938
# 699                        CCSC(=O)OCC[N+](C)(C)C.[Cl-]       CHEMBL102637
# ...                                                 ...                ...
# 2400  O=C(CCCCCCCNc1c2c(nc3cc(Cl)cc(Cl)c13)CCCC2)NCC...      CHEMBL4590945
# 271   S=C(CCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c2c...      CHEMBL4469239
# 1883  O=C(CCCCCCCNc1c2c(nc3ccccc13)CCCC2)NCCc1c[nH]c...      CHEMBL4579667
# 5478  COc1ccc2[nH]cc(CCNC(=O)CCCCNc3c4c(nc5ccccc35)C...      CHEMBL4455677
# 4707  COc1ccc2[nH]cc(CCNC(=O)CCCCCCNc3c4c(nc5ccccc35...       CHEMBL382260
#
#      standard_type standard_units  standard_value     class  Label     pIC50
# 5037          IC50             nM    4.960000e+07  inactive      0 -7.695482
# 4468          IC50             nM    1.862000e+07  inactive      0 -7.269980
# 420           IC50             nM    1.512000e+07  inactive      0 -7.179552
# 3024          IC50             nM    1.158777e+07  inactive      0 -7.064000
# 699           IC50             nM    1.000000e+07  inactive      0 -7.000000
# ...            ...            ...             ...       ...    ...       ...
# 2400          IC50             nM    5.000000e-06    active      1  5.301030
# 271           IC50             nM    5.000000e-06    active      1  5.301030
# 1883          IC50             nM    5.000000e-06    active      1  5.301030
# 5478          IC50             nM    5.000000e-06    active      1  5.301030
# 4707          IC50             nM    5.000000e-06    active      1  5.301030
#
# [5734 rows x 8 columns]

# %%
data_class_active_inactive.drop(['standard_type', 'standard_units', 'standard_value'], axis=1, inplace=True)

# %%
data_class_active_inactive
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...      CHEMBL3234040
# 1     CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...      CHEMBL4854913
# 2     [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...      CHEMBL1761995
# 3                   CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl      CHEMBL1200970
# 4                      Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1      CHEMBL4760651
# ...                                                 ...                ...
# 6119  O=C(CCCNc1c2c(nc3ccccc13)CCCC2)CCCNc1c2c(nc3cc...       CHEMBL238230
# 6120                           Clc1cccc2c1CN1CCCCCC1=N2       CHEMBL161880
# 6122  O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...      CHEMBL4859041
# 6123  CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...      CHEMBL5090352
# 6124          CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C       CHEMBL381926
#
#          class  Label     pIC50
# 0       active      1 -1.260071
# 1       active      1  0.387216
# 2       active      1 -1.903090
# 3     inactive      0 -6.008600
# 4       active      1 -2.250420
# ...        ...    ...       ...
# 6119    active      1 -0.262451
# 6120    active      1 -3.230449
# 6122    active      1 -2.714330
# 6123  inactive      0 -5.000000
# 6124    active      1 -1.913814
#
# [5734 rows x 5 columns]

# %%
data_class_active_inactive.set_index('molecule_chembl_id', inplace=True)

# %%
data_class_active_inactive
# Out:
#                                                      canonical_smiles  \
# molecule_chembl_id
# CHEMBL3234040       CC1=CC2Cc3nc4cc(Cl)ccc4c(NCc4ccc(CNC(=O)c5cc(O...
# CHEMBL4854913       CC1=CC2Cc3nc4cc(Cl)ccc4c(NCCCCCCCCC(=O)N4CCNC(...
# CHEMBL1761995       [Br-].[Br-].c1ccc2c(c1)ccc[n+]2CCCCCCCC[n+]1cc...
# CHEMBL1200970                     CCN(CC)C(C)CN1c2ccccc2Sc2ccccc21.Cl
# CHEMBL4760651                        Clc1ccc(CNC2CCN(Cc3ccccc3)C2)cc1
# ...                                                               ...
# CHEMBL238230        O=C(CCCNc1c2c(nc3ccccc13)CCCC2)CCCNc1c2c(nc3cc...
# CHEMBL161880                                 Clc1cccc2c1CN1CCCCCC1=N2
# CHEMBL4859041       O=C(CC1CCN(Cc2ccc(F)cc2)CC1)Nc1n[nH]c2cc(-c3cc...
# CHEMBL5090352       CO[C@H]1C=C2[C@H]3CN(Cc4cc5c(cc43)OCO5)[C@H]2C...
# CHEMBL381926                CCNC(=O)Oc1ccc2c(c1)[C@]1(C)CCO[C@@H]1N2C
#
#                        class  Label     pIC50
# molecule_chembl_id
# CHEMBL3234040         active      1 -1.260071
# CHEMBL4854913         active      1  0.387216
# CHEMBL1761995         active      1 -1.903090
# CHEMBL1200970       inactive      0 -6.008600
# CHEMBL4760651         active      1 -2.250420
# ...                      ...    ...       ...
# CHEMBL238230          active      1 -0.262451
# CHEMBL161880          active      1 -3.230449
# CHEMBL4859041         active      1 -2.714330
# CHEMBL5090352       inactive      0 -5.000000
# CHEMBL381926          active      1 -1.913814
#
# [5734 rows x 4 columns]

# %% [markdown]
# ## 9. Save Data

# %%
data_class_active_inactive.to_csv('data_class_active_inactive.csv', index=False)

# %%
data_class_active_inactive['canonical_smiles'].to_csv('data_labelled.smi', header=False, sep='\t')
