# %% [markdown]
# # Library Filtering
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Stef0916/chemoinformatics-bioinformatics/blob/main/cheminformatics-workflow/notebooks/2-Library_filtering.ipynb)

# %% [markdown]
# ## Content
#
# 1. [Load DataSet from PubChem](#1)
# 2. [Remove Nan](#2)
# 3. [Remove Duplicates](#3)
# 4. [Molecues Visualization](#4)
# 5. [Remove Inconclusive Results](#5)
# 6. [Remove Active Agonist = Toxic](#6)
# 7. [Remove Weak Compounds](#7)
# 8. [Save the DataSet](#8)

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.9.1

# %%
# !pip install mols2grid
# Out:
# Collecting mols2grid
#   Downloading mols2grid-2.0.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (7.7.1)
# Requirement already satisfied: jinja2>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mols2grid) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mols2grid) (1.5.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.0->mols2grid) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mols2grid) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mols2grid) (2023.3.post1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->mols2grid) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.19.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.21)
# Installing collected packages: jedi, mols2grid
# Successfully installed jedi-0.19.1 mols2grid-2.0.0

# %%
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import Draw, PandasTools
import copy
import mols2grid

# %% [markdown]
# ## 1. Load DataSet from PubChem<a name = 1></a>

# %%
data = pd.read_csv('AID_1259247_datatable.csv')

# %%
data
# Out:
#                   PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                        RESULT_TYPE          NaN          NaN
# 1                       RESULT_DESCR          NaN          NaN
# 2                        RESULT_UNIT          NaN          NaN
# 3     RESULT_IS_ACTIVE_CONCENTRATION          NaN          NaN
# 4                                  1  144211407.0      91754.0
# ...                              ...          ...          ...
# 9666                            9663  251919788.0       8304.0
# 9667                            9664  251919825.0       1127.0
# 9668                            9665  251919641.0     104856.0
# 9669                            9666  251919642.0      47289.0
# 9670                            9667  251919666.0      24723.0
#
#                           PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     CC(C)(C)C1=CC=C(C=C1)CSC2=C(C(=O)N(N=C2)C(C)(C...
# ...                                                 ...
# 9666                              CC(C)OP(OC(C)C)OC(C)C
# 9667                                            C1CCSC1
# 9668                          CN(CCCC(C1=CN=CC=C1)O)N=O
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
# 9670                                CCOP(=O)(OCC)SCCSCC
#
#      PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                         NaN                     NaN                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                      Active                   100.0                   NaN
# ...                       ...                     ...                   ...
# 9666                 Inactive                     0.0                   NaN
# 9667                 Inactive                     0.0                   NaN
# 9668                 Inactive                     0.0                   NaN
# 9669                 Inactive                     0.0                   NaN
# 9670                 Inactive                     0.0                   NaN
#
#       PUBCHEM_ASSAYDATA_COMMENT  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 9666                        NaN
# 9667                        NaN
# 9668                        NaN
# 9669                        NaN
# 9670                        NaN
#
#                                        Activity Summary  \
# 0                                                STRING
# 1     Type of compound activity based on both the CA...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                     Antagonist Activity  \
# 0                                                STRING
# 1     Type of compound activity in the CAR antagonis...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                 Antagonist Potency (uM)  \
# 0                                                 FLOAT
# 1     The concentration of sample yielding half-maxi...
# 2                                            MICROMOLAR
# 3                                                  TRUE
# 4                                             0.0200875
# ...                                                 ...
# 9666                                                NaN
# 9667                                                NaN
# 9668                                                NaN
# 9669                                                NaN
# 9670                                                NaN
#
#          Antagonist Efficacy (%)  \
# 0                          FLOAT
# 1     Percent inhibition of CAR.
# 2                        PERCENT
# 3                            NaN
# 4                       -109.405
# ...                          ...
# 9666                           0
# 9667                           0
# 9668                           0
# 9669                           0
# 9670                           0
#
#                                      Viability Activity  \
# 0                                                STRING
# 1     Type of compound activity in the cell viabilit...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                  Viability Potency (uM)  \
# 0                                                 FLOAT
# 1     The concentration of sample yielding half-maxi...
# 2                                            MICROMOLAR
# 3                                                   NaN
# 4                                             0.0660073
# ...                                                 ...
# 9666                                                NaN
# 9667                                                NaN
# 9668                                                NaN
# 9669                                                NaN
# 9670                                                NaN
#
#                      Viability Efficacy (%)                     Sample Source
# 0                                     FLOAT                            STRING
# 1     Percent inhibition of cell viability.        Where sample was obtained.
# 2                                   PERCENT                               NaN
# 3                                       NaN                               NaN
# 4                                  -45.9524                             SIGMA
# ...                                     ...                               ...
# 9666                                      0                       TCI America
# 9667                                      0                       TCI America
# 9668                                      0  Toronto Research Chemicals, Inc.
# 9669                                      0  Toronto Research Chemicals, Inc.
# 9670                                      0  Toronto Research Chemicals, Inc.
#
# [9671 rows x 16 columns]

# %%
# SMILES are in a column named 'PUBCHEM_EXT_DATASOURCE_SMILES'
data.rename(columns={'PUBCHEM_EXT_DATASOURCE_SMILES': 'PUBCHEM_SMILES'}, inplace=True)
data
# Out:
#                   PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                        RESULT_TYPE          NaN          NaN
# 1                       RESULT_DESCR          NaN          NaN
# 2                        RESULT_UNIT          NaN          NaN
# 3     RESULT_IS_ACTIVE_CONCENTRATION          NaN          NaN
# 4                                  1  144211407.0      91754.0
# ...                              ...          ...          ...
# 9666                            9663  251919788.0       8304.0
# 9667                            9664  251919825.0       1127.0
# 9668                            9665  251919641.0     104856.0
# 9669                            9666  251919642.0      47289.0
# 9670                            9667  251919666.0      24723.0
#
#                                          PUBCHEM_SMILES  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     CC(C)(C)C1=CC=C(C=C1)CSC2=C(C(=O)N(N=C2)C(C)(C...
# ...                                                 ...
# 9666                              CC(C)OP(OC(C)C)OC(C)C
# 9667                                            C1CCSC1
# 9668                          CN(CCCC(C1=CN=CC=C1)O)N=O
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
# 9670                                CCOP(=O)(OCC)SCCSCC
#
#      PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                         NaN                     NaN                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                      Active                   100.0                   NaN
# ...                       ...                     ...                   ...
# 9666                 Inactive                     0.0                   NaN
# 9667                 Inactive                     0.0                   NaN
# 9668                 Inactive                     0.0                   NaN
# 9669                 Inactive                     0.0                   NaN
# 9670                 Inactive                     0.0                   NaN
#
#       PUBCHEM_ASSAYDATA_COMMENT  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 9666                        NaN
# 9667                        NaN
# 9668                        NaN
# 9669                        NaN
# 9670                        NaN
#
#                                        Activity Summary  \
# 0                                                STRING
# 1     Type of compound activity based on both the CA...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                     Antagonist Activity  \
# 0                                                STRING
# 1     Type of compound activity in the CAR antagonis...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                 Antagonist Potency (uM)  \
# 0                                                 FLOAT
# 1     The concentration of sample yielding half-maxi...
# 2                                            MICROMOLAR
# 3                                                  TRUE
# 4                                             0.0200875
# ...                                                 ...
# 9666                                                NaN
# 9667                                                NaN
# 9668                                                NaN
# 9669                                                NaN
# 9670                                                NaN
#
#          Antagonist Efficacy (%)  \
# 0                          FLOAT
# 1     Percent inhibition of CAR.
# 2                        PERCENT
# 3                            NaN
# 4                       -109.405
# ...                          ...
# 9666                           0
# 9667                           0
# 9668                           0
# 9669                           0
# 9670                           0
#
#                                      Viability Activity  \
# 0                                                STRING
# 1     Type of compound activity in the cell viabilit...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                  Viability Potency (uM)  \
# 0                                                 FLOAT
# 1     The concentration of sample yielding half-maxi...
# 2                                            MICROMOLAR
# 3                                                   NaN
# 4                                             0.0660073
# ...                                                 ...
# 9666                                                NaN
# 9667                                                NaN
# 9668                                                NaN
# 9669                                                NaN
# 9670                                                NaN
#
#                      Viability Efficacy (%)                     Sample Source
# 0                                     FLOAT                            STRING
# 1     Percent inhibition of cell viability.        Where sample was obtained.
# 2                                   PERCENT                               NaN
# 3                                       NaN                               NaN
# 4                                  -45.9524                             SIGMA
# ...                                     ...                               ...
# 9666                                      0                       TCI America
# 9667                                      0                       TCI America
# 9668                                      0  Toronto Research Chemicals, Inc.
# 9669                                      0  Toronto Research Chemicals, Inc.
# 9670                                      0  Toronto Research Chemicals, Inc.
#
# [9671 rows x 16 columns]

# %%
data.columns
# Out:
# Index(['PUBCHEM_RESULT_TAG', 'PUBCHEM_SID', 'PUBCHEM_CID', 'PUBCHEM_SMILES',
#        'PUBCHEM_ACTIVITY_OUTCOME', 'PUBCHEM_ACTIVITY_SCORE',
#        'PUBCHEM_ACTIVITY_URL', 'PUBCHEM_ASSAYDATA_COMMENT', 'Activity Summary',
#        'Antagonist Activity', 'Antagonist Potency (uM)',
#        'Antagonist Efficacy (%)', 'Viability Activity',
#        'Viability Potency (uM)', 'Viability Efficacy (%)', 'Sample Source'],
#       dtype='object')

# %%
keep_columns = ['PUBCHEM_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME', 'Antagonist Activity', 'Viability Activity', 'Antagonist Efficacy (%)']

# %%
data = data.loc[:, keep_columns]
data
# Out:
#                                          PUBCHEM_SMILES  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     CC(C)(C)C1=CC=C(C=C1)CSC2=C(C(=O)N(N=C2)C(C)(C...
# ...                                                 ...
# 9666                              CC(C)OP(OC(C)C)OC(C)C
# 9667                                            C1CCSC1
# 9668                          CN(CCCC(C1=CN=CC=C1)O)N=O
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
# 9670                                CCOP(=O)(OCC)SCCSCC
#
#      PUBCHEM_ACTIVITY_OUTCOME  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                      Active
# ...                       ...
# 9666                 Inactive
# 9667                 Inactive
# 9668                 Inactive
# 9669                 Inactive
# 9670                 Inactive
#
#                                     Antagonist Activity  \
# 0                                                STRING
# 1     Type of compound activity in the CAR antagonis...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#                                      Viability Activity  \
# 0                                                STRING
# 1     Type of compound activity in the cell viabilit...
# 2                                                   NaN
# 3                                                   NaN
# 4                                     active antagonist
# ...                                                 ...
# 9666                                           inactive
# 9667                                           inactive
# 9668                                           inactive
# 9669                                           inactive
# 9670                                           inactive
#
#          Antagonist Efficacy (%)
# 0                          FLOAT
# 1     Percent inhibition of CAR.
# 2                        PERCENT
# 3                            NaN
# 4                       -109.405
# ...                          ...
# 9666                           0
# 9667                           0
# 9668                           0
# 9669                           0
# 9670                           0
#
# [9671 rows x 5 columns]

# %%
len(data)
# Out:
# 9671

# %% [markdown]
# ## 2. Remove NaN<a name = 2></a>

# %%
data_non_nan = data.loc[data['PUBCHEM_SMILES'].notna()]
len(data_non_nan)
# Out:
# 9524

# %%
data_non_nan.loc[data['PUBCHEM_ACTIVITY_OUTCOME'].isna()]
# Out:
# Empty DataFrame
# Columns: [PUBCHEM_SMILES, PUBCHEM_ACTIVITY_OUTCOME, Antagonist Activity, Viability Activity, Antagonist Efficacy (%)]
# Index: []

# %%
data_non_nan.loc[data['Viability Activity'].isna()]
# Out:
# Empty DataFrame
# Columns: [PUBCHEM_SMILES, PUBCHEM_ACTIVITY_OUTCOME, Antagonist Activity, Viability Activity, Antagonist Efficacy (%)]
# Index: []

# %%
data_non_nan.loc[data['Antagonist Efficacy (%)'].isna()]
# Out:
#                                          PUBCHEM_SMILES  \
# 1459              COC1=C(C=CC(=C1)C2=NNC(=O)C=C2)OC(F)F
# 1460  C[C@@]1(C(=O)N2[C@H](C(=O)N3CCC[C@H]3[C@@]2(O1...
# 1461  CCC(COC(=O)C1=CC(=C(C(=C1)OC)OC)OC)(C2=CC=CC=C...
# 1462                   C1=CC=C(C=C1)CC2=C(C=CC(=C2)Cl)O
# 1463  CC(=O)[C@]1(CC[C@@H]2[C@@]1(CC[C@H]3[C@H]2CCC4...
# ...                                                 ...
# 3095                                    CC1=CC(=CC=C1)C
# 3096               C1=CC(=C(C=C1C2=CC(=C(C=C2)N)Cl)Cl)N
# 3097                     CCCCCCCCCCCCCCCCCC(=O)OCC(CO)O
# 3098                                         CCOC(=O)CS
# 3099  C[C@]12CC[C@H](C[C@@H]1CC[C@@H]3[C@@H]2CC[C@]4...
#
#      PUBCHEM_ACTIVITY_OUTCOME      Antagonist Activity Viability Activity  \
# 1459             Inconclusive  inconclusive antagonist           inactive
# 1460             Inconclusive  inconclusive antagonist           inactive
# 1461             Inconclusive  inconclusive antagonist           inactive
# 1462             Inconclusive  inconclusive antagonist           inactive
# 1463             Inconclusive  inconclusive antagonist           inactive
# ...                       ...                      ...                ...
# 3095             Inconclusive             inconclusive           inactive
# 3096             Inconclusive             inconclusive           inactive
# 3097             Inconclusive             inconclusive           inactive
# 3098             Inconclusive             inconclusive           inactive
# 3099             Inconclusive             inconclusive           inactive
#
#      Antagonist Efficacy (%)
# 1459                     NaN
# 1460                     NaN
# 1461                     NaN
# 1462                     NaN
# 1463                     NaN
# ...                      ...
# 3095                     NaN
# 3096                     NaN
# 3097                     NaN
# 3098                     NaN
# 3099                     NaN
#
# [504 rows x 5 columns]

# %%
data_non_nan = data_non_nan.loc[data['Antagonist Efficacy (%)'].notna()]

# %%
data_non_nan.sort_values(by='Antagonist Efficacy (%)')
# Out:
#                                          PUBCHEM_SMILES  \
# 2220                 C1=CC=C2C(=C1)C(=O)C(=C(C2=O)Cl)Cl
# 636                               C1=CC=C(C(=C1)CCl)CCl
# 488                     CN(C(=O)NC1=CC(=C(C=C1)Br)Cl)OC
# 2044  C/C=C/C(=O)OC1=C(C=C(C=C1[N+](=O)[O-])[N+](=O)...
# 2043  CN(C)C(=O)C(CCN1CCC(CC1)(C2=CC=C(C=C2)Cl)O)(C3...
# ...                                                 ...
# 2350         C1CCOC(C1)N2C=NC3=C(N=CN=C32)NCC4=CC=CC=C4
# 2718                                  C=CC(=O)OCCC(=O)O
# 2351                                 CC1=CC(=C(C=C1)N)N
# 2352        CC(C)OC1=CC2=C(C=C1)C(=O)C(=CO2)C3=CC=CC=C3
# 2353                                C1=CC(=C(C=C1Cl)N)N
#
#      PUBCHEM_ACTIVITY_OUTCOME      Antagonist Activity Viability Activity  \
# 2220             Inconclusive  inconclusive antagonist  active antagonist
# 636                    Active        active antagonist           inactive
# 488                    Active        active antagonist           inactive
# 2044             Inconclusive        active antagonist  active antagonist
# 2043             Inconclusive        active antagonist  active antagonist
# ...                       ...                      ...                ...
# 2350             Inconclusive           active agonist           inactive
# 2718             Inconclusive     inconclusive agonist           inactive
# 2351             Inconclusive           active agonist           inactive
# 2352             Inconclusive           active agonist           inactive
# 2353             Inconclusive           active agonist           inactive
#
#      Antagonist Efficacy (%)
# 2220                -10.5135
# 636                 -100.025
# 488                  -100.03
# 2044                -100.048
# 2043                -100.118
# ...                      ...
# 2350                 97.4415
# 2718                 97.8793
# 2351                  99.046
# 2352                  99.467
# 2353                 99.5291
#
# [9020 rows x 5 columns]

# %% [markdown]
# ## 3. Remove Duplicates<a name = 3></a>

# %%
len(data_non_nan['PUBCHEM_SMILES'].unique())
# Out:
# 7376

# %%
data_non_nan.loc[data_non_nan['PUBCHEM_SMILES'].duplicated()].sort_values(by='PUBCHEM_SMILES')
# Out:
#                                 PUBCHEM_SMILES PUBCHEM_ACTIVITY_OUTCOME  \
# 8671                                  B(O)(O)O                 Inactive
# 8310                   B(OC(C)C)(OC(C)C)OC(C)C                 Inactive
# 7052                              C(#N)C(Br)Br                 Inactive
# 90         C(#N)C1=C(C(=C(C(=C1Cl)Cl)Cl)C#N)Cl                   Active
# 8309                              C(#N)N=C(N)N                 Inactive
# ...                                        ...                      ...
# 9322                  [NH2-].[NH2-].Cl[Pt+2]Cl                 Inactive
# 6925                     [NH4+].NS(=O)(=O)[O-]                 Inactive
# 8727                 [NH4+].[N+](=O)([O-])[O-]                 Inactive
# 8744                   [NH4+].[O-]Cl(=O)(=O)=O                 Inactive
# 8176  [O-]S(=O)(=O)OOS(=O)(=O)[O-].[Na+].[Na+]                 Inactive
#
#      Antagonist Activity Viability Activity Antagonist Efficacy (%)
# 8671            inactive           inactive                       0
# 8310            inactive           inactive                       0
# 7052            inactive           inactive                       0
# 90     active antagonist  active antagonist                -102.965
# 8309            inactive           inactive                       0
# ...                  ...                ...                     ...
# 9322            inactive           inactive                       0
# 6925            inactive           inactive                       0
# 8727            inactive           inactive                       0
# 8744            inactive           inactive                       0
# 8176            inactive           inactive                       0
#
# [1644 rows x 5 columns]

# %%
data_clean = data_non_nan.loc[~data_non_nan['PUBCHEM_SMILES'].duplicated()]
len(data_clean)
# Out:
# 7376

# %% [markdown]
# ## 4. Molecule Visualization<a name = 4></a>

# %%
data_clean = data_clean.copy()
data_clean['Molecule'] = data_clean['PUBCHEM_SMILES'].apply(lambda x: Chem.MolFromSmiles(x) if x is not None else None)
# Out:
# [16:27:31] Explicit valence for atom # 1 Si, 8, is greater than permitted
# [16:27:32] WARNING: not removing hydrogen atom without neighbors

# %%
data_clean.sort_values(by='Antagonist Efficacy (%)')
# Out:
#                                          PUBCHEM_SMILES  \
# 636                               C1=CC=C(C(=C1)CCl)CCl
# 488                     CN(C(=O)NC1=CC(=C(C=C1)Br)Cl)OC
# 2044  C/C=C/C(=O)OC1=C(C=C(C=C1[N+](=O)[O-])[N+](=O)...
# 2043  CN(C)C(=O)C(CCN1CCC(CC1)(C2=CC=C(C=C2)Cl)O)(C3...
# 487   COC1CN(CCC1NC(=O)C2=CC(=C(C=C2OC)N)Cl)CCCOC3=C...
# ...                                                 ...
# 2350         C1CCOC(C1)N2C=NC3=C(N=CN=C32)NCC4=CC=CC=C4
# 2718                                  C=CC(=O)OCCC(=O)O
# 2351                                 CC1=CC(=C(C=C1)N)N
# 2352        CC(C)OC1=CC2=C(C=C1)C(=O)C(=CO2)C3=CC=CC=C3
# 2353                                C1=CC(=C(C=C1Cl)N)N
#
#      PUBCHEM_ACTIVITY_OUTCOME   Antagonist Activity Viability Activity  \
# 636                    Active     active antagonist           inactive
# 488                    Active     active antagonist           inactive
# 2044             Inconclusive     active antagonist  active antagonist
# 2043             Inconclusive     active antagonist  active antagonist
# 487                    Active     active antagonist           inactive
# ...                       ...                   ...                ...
# 2350             Inconclusive        active agonist           inactive
# 2718             Inconclusive  inconclusive agonist           inactive
# 2351             Inconclusive        active agonist           inactive
# 2352             Inconclusive        active agonist           inactive
# 2353             Inconclusive        active agonist           inactive
#
#      Antagonist Efficacy (%)                                          Molecule
# 636                 -100.025  <rdkit.Chem.rdchem.Mol object at 0x7ec59728a030>
# 488                  -100.03  <rdkit.Chem.rdchem.Mol object at 0x7ec59729ea40>
# 2044                -100.048  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c28f0>
# 2043                -100.118  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c2880>
# 487                 -100.191  <rdkit.Chem.rdchem.Mol object at 0x7ec59729e9d0>
# ...                      ...                                               ...
# 2350                 97.4415  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c9070>
# 2718                 97.8793  <rdkit.Chem.rdchem.Mol object at 0x7ec597284660>
# 2351                  99.046  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c90e0>
# 2352                  99.467  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c9150>
# 2353                 99.5291  <rdkit.Chem.rdchem.Mol object at 0x7ec5972c91c0>
#
# [7376 rows x 6 columns]

# %%
data_clean['Antagonist Efficacy (%)'].describe()
# Out:
# count     7376
# unique    2080
# top          0
# freq      5286
# Name: Antagonist Efficacy (%), dtype: object

# %%
data = data_clean.copy()
data_clean['Antagonist Efficacy (%)'] = data_clean['Antagonist Efficacy (%)'].astype('float64')

# %%
data_clean['Antagonist Efficacy (%)'].dtype
# Out:
# dtype('float64')

# %%
mols2grid.display(data_clean, mol_col = 'Molecule', subset=['PUBCHEM_ACTIVITY_OUTCOME', 'Antagonist Activity', 'Antagonist Efficacy (%)'],
                  transform={"Antagonist Efficacy (%)": lambda x: f"{x:.2f}"})
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 5. Remove Inconclusive Results<a name = 5></a>

# %%
data_clean['PUBCHEM_ACTIVITY_OUTCOME'].unique()
# Out:
# array(['Active', 'Inconclusive', 'Inactive'], dtype=object)

# %%
data_clean.loc[data_clean['PUBCHEM_ACTIVITY_OUTCOME'] == 'Inconclusive']
# Out:
#                                          PUBCHEM_SMILES  \
# 1112               CCC1=CC(=C(C(=C1)C(C)(C)C)O)C(C)(C)C
# 1113      CN(C1CCCCC1)C(=O)CCCOC2=CC3=C(C=C2)NC(=O)C=C3
# 1114  C1CCN(CC1)C2=NC(=NC3=C2N=C(N=C3N4CCCCC4)N(CCO)...
# 1115    C(CS)C(=O)OCC(COC(=O)CCS)(COC(=O)CCS)COC(=O)CCS
# 1116                    C1=CC=C(C=C1)NC2=CC=C(C=C2)N.Cl
# ...                                                 ...
# 3060  C1=CC(=CC=C1N=NC2=CC(=C(C=C2)O)C(=O)O)[N+](=O)...
# 3062               C1=CC=C(C=C1)N=NC2=C(N=C(C=C2)N)N.Cl
# 3063          CN(C)C1=CC=C(C=C1)C(=O)C2=CC=C(C=C2)N(C)C
# 3064           C1=CSC(=C1)C(=O)NC2=NC=C(S2)[N+](=O)[O-]
# 3065                                CN(C)C1=CC=C(C=C1)N
#
#      PUBCHEM_ACTIVITY_OUTCOME      Antagonist Activity  \
# 1112             Inconclusive  inconclusive antagonist
# 1113             Inconclusive  inconclusive antagonist
# 1114             Inconclusive  inconclusive antagonist
# 1115             Inconclusive  inconclusive antagonist
# 1116             Inconclusive  inconclusive antagonist
# ...                       ...                      ...
# 3060             Inconclusive           active agonist
# 3062             Inconclusive     inconclusive agonist
# 3063             Inconclusive     inconclusive agonist
# 3064             Inconclusive     inconclusive agonist
# 3065             Inconclusive     inconclusive agonist
#
#            Viability Activity  Antagonist Efficacy (%)  \
# 1112                 inactive                -158.4640
# 1113                 inactive                -151.7800
# 1114           active agonist                -144.6710
# 1115                 inactive                -143.0470
# 1116  inconclusive antagonist                -138.3270
# ...                       ...                      ...
# 3060  inconclusive antagonist                 194.8110
# 3062        active antagonist                  34.0911
# 3063        active antagonist                  58.4712
# 3064        active antagonist                  71.1967
# 3065  inconclusive antagonist                  76.3607
#
#                                               Molecule
# 1112  <rdkit.Chem.rdchem.Mol object at 0x7ec5972a9700>
# 1113  <rdkit.Chem.rdchem.Mol object at 0x7ec5972a9770>
# 1114  <rdkit.Chem.rdchem.Mol object at 0x7ec5972a97e0>
# 1115  <rdkit.Chem.rdchem.Mol object at 0x7ec5972a9850>
# 1116  <rdkit.Chem.rdchem.Mol object at 0x7ec5972a98c0>
# ...                                                ...
# 3060  <rdkit.Chem.rdchem.Mol object at 0x7ec5972852a0>
# 3062  <rdkit.Chem.rdchem.Mol object at 0x7ec597285310>
# 3063  <rdkit.Chem.rdchem.Mol object at 0x7ec597285380>
# 3064  <rdkit.Chem.rdchem.Mol object at 0x7ec5972853f0>
# 3065  <rdkit.Chem.rdchem.Mol object at 0x7ec597285460>
#
# [1155 rows x 6 columns]

# %%
data_clean = data_clean.loc[data_clean['PUBCHEM_ACTIVITY_OUTCOME'] != 'Inconclusive']
data_clean.sort_values(by='Antagonist Efficacy (%)')
# Out:
#                                          PUBCHEM_SMILES  \
# 191       CC1=CC(=CC(=C1O)C)C(C)(C)C2=CC(=C(C(=C2)C)O)C
# 171   C1=CC(=CC2=NC3=C(C=CC(=C3)N)C=C21)N.C1=CC(=CC2...
# 68    C1=CC(=C2C(=C1NCCNCCO)C(=O)C3=C(C=CC(=C3C2=O)O...
# 193   CN1C2=NC(=NC=C2CN(C1=O)C3=CC=CC=C3Br)NC4=CC5=C...
# 347   CC1=C(C(C(=C(N1)C)C(=O)OC/C=C/C2=CC=CC=C2)C3=C...
# ...                                                 ...
# 4981                              CC1CC(OC(O1)C)OC(=O)C
# 4980                          C1=C(C(=CC(=C1Cl)Cl)Cl)Cl
# 4979  CC(=C)C(=O)OCCC(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...
# 4977             CCCCC(CC)COC(=O)CCCCC(=O)OCC1=CC=CC=C1
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
#
#      PUBCHEM_ACTIVITY_OUTCOME Antagonist Activity       Viability Activity  \
# 191                    Active   active antagonist                 inactive
# 171                    Active   active antagonist           active agonist
# 68                     Active   active antagonist        active antagonist
# 193                    Active   active antagonist  inconclusive antagonist
# 347                    Active   active antagonist                 inactive
# ...                       ...                 ...                      ...
# 4981                 Inactive            inactive                 inactive
# 4980                 Inactive            inactive                 inactive
# 4979                 Inactive            inactive                 inactive
# 4977                 Inactive            inactive                 inactive
# 9669                 Inactive            inactive                 inactive
#
#       Antagonist Efficacy (%)  \
# 191                  -177.383
# 171                  -142.931
# 68                   -142.058
# 193                  -135.678
# 347                  -135.491
# ...                       ...
# 4981                    0.000
# 4980                    0.000
# 4979                    0.000
# 4977                    0.000
# 9669                    0.000
#
#                                               Molecule
# 191   <rdkit.Chem.rdchem.Mol object at 0x7ec597273df0>
# 171   <rdkit.Chem.rdchem.Mol object at 0x7ec597273680>
# 68    <rdkit.Chem.rdchem.Mol object at 0x7ec597271310>
# 193   <rdkit.Chem.rdchem.Mol object at 0x7ec597273e60>
# 347   <rdkit.Chem.rdchem.Mol object at 0x7ec5972974c0>
# ...                                                ...
# 4981  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9cb0>
# 4980  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9c40>
# 4979  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9bd0>
# 4977  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9af0>
# 9669  <rdkit.Chem.rdchem.Mol object at 0x7ec597163140>
#
# [6221 rows x 6 columns]

# %% [markdown]
# ## 6. Removing Active Agonist = Toxic<a name = 6></a>

# %%
data_clean.loc[data_clean['Viability Activity'] == 'active agonist']
# Out:
#                                          PUBCHEM_SMILES  \
# 21    CC[C@@]1(C2=C(COC1=O)C(=O)N3CC4=CC5=C(C=CC(=C5...
# 171   C1=CC(=CC2=NC3=C(C=CC(=C3)N)C=C21)N.C1=CC(=CC2...
# 288   C[N+]1=C2C=C(C=CC2=CC3=C1C=C(C=C3)N)N.C1=CC(=C...
# 810                      CC1=C(C(=O)OC2=C1C=CC(=C2)O)Cl
# 3103  CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)C[C@@H]...
# 3119            C1=CC=C2C(=C1)C(=O)C3=CC=CC=C3N2CC(=O)O
# 3135  C1=CC=C2C(=C1)C(=O)OC23C4=C(C=C(C=C4)O)OC5=C3C...
#
#      PUBCHEM_ACTIVITY_OUTCOME Antagonist Activity Viability Activity  \
# 21                     Active   active antagonist     active agonist
# 171                    Active   active antagonist     active agonist
# 288                    Active   active antagonist     active agonist
# 810                    Active   active antagonist     active agonist
# 3103                 Inactive            inactive     active agonist
# 3119                 Inactive            inactive     active agonist
# 3135                 Inactive            inactive     active agonist
#
#       Antagonist Efficacy (%)  \
# 21                  -108.7420
# 171                 -142.9310
# 288                  -80.1402
# 810                  -55.1457
# 3103                   0.0000
# 3119                   0.0000
# 3135                   0.0000
#
#                                               Molecule
# 21    <rdkit.Chem.rdchem.Mol object at 0x7ec597270120>
# 171   <rdkit.Chem.rdchem.Mol object at 0x7ec597273680>
# 288   <rdkit.Chem.rdchem.Mol object at 0x7ec597296110>
# 810   <rdkit.Chem.rdchem.Mol object at 0x7ec5972a6260>
# 3103  <rdkit.Chem.rdchem.Mol object at 0x7ec5972855b0>
# 3119  <rdkit.Chem.rdchem.Mol object at 0x7ec597285a10>
# 3135  <rdkit.Chem.rdchem.Mol object at 0x7ec597285f50>

# %%
len(data_clean.loc[data_clean['Viability Activity'] == 'active agonist'])
# Out:
# 7

# %%
data_clean = data_clean.loc[data_clean['Viability Activity'] != 'active agonist']

# %%
len(data_clean)
# Out:
# 6214

# %% [markdown]
# ## 7. Remove Weak Compounds<a name = 7></a>

# %%
data_clean.sort_values(by='Antagonist Efficacy (%)')
# Out:
#                                          PUBCHEM_SMILES  \
# 191       CC1=CC(=CC(=C1O)C)C(C)(C)C2=CC(=C(C(=C2)C)O)C
# 68    C1=CC(=C2C(=C1NCCNCCO)C(=O)C3=C(C=CC(=C3C2=O)O...
# 193   CN1C2=NC(=NC=C2CN(C1=O)C3=CC=CC=C3Br)NC4=CC5=C...
# 347   CC1=C(C(C(=C(N1)C)C(=O)OC/C=C/C2=CC=CC=C2)C3=C...
# 306   C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C)O)CC[C@@...
# ...                                                 ...
# 4983  C(C(C(C(C(F)(F)S(=O)(=O)[O-])(F)F)(F)F)(F)F)(C...
# 4982  C(=O)(C(C(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)F)(F)F...
# 4981                              CC1CC(OC(O1)C)OC(=O)C
# 4979  CC(=C)C(=O)OCCC(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
#
#      PUBCHEM_ACTIVITY_OUTCOME Antagonist Activity       Viability Activity  \
# 191                    Active   active antagonist                 inactive
# 68                     Active   active antagonist        active antagonist
# 193                    Active   active antagonist  inconclusive antagonist
# 347                    Active   active antagonist                 inactive
# 306                    Active   active antagonist                 inactive
# ...                       ...                 ...                      ...
# 4983                 Inactive            inactive                 inactive
# 4982                 Inactive            inactive                 inactive
# 4981                 Inactive            inactive                 inactive
# 4979                 Inactive            inactive                 inactive
# 9669                 Inactive            inactive                 inactive
#
#       Antagonist Efficacy (%)  \
# 191                  -177.383
# 68                   -142.058
# 193                  -135.678
# 347                  -135.491
# 306                  -135.449
# ...                       ...
# 4983                    0.000
# 4982                    0.000
# 4981                    0.000
# 4979                    0.000
# 9669                    0.000
#
#                                               Molecule
# 191   <rdkit.Chem.rdchem.Mol object at 0x7ec597273df0>
# 68    <rdkit.Chem.rdchem.Mol object at 0x7ec597271310>
# 193   <rdkit.Chem.rdchem.Mol object at 0x7ec597273e60>
# 347   <rdkit.Chem.rdchem.Mol object at 0x7ec5972974c0>
# 306   <rdkit.Chem.rdchem.Mol object at 0x7ec5972966c0>
# ...                                                ...
# 4983  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9d90>
# 4982  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9d20>
# 4981  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9cb0>
# 4979  <rdkit.Chem.rdchem.Mol object at 0x7ec5972f9bd0>
# 9669  <rdkit.Chem.rdchem.Mol object at 0x7ec597163140>
#
# [6214 rows x 6 columns]

# %%
mask = ~((data_clean['Antagonist Efficacy (%)'] > -40) &
         (data_clean['PUBCHEM_ACTIVITY_OUTCOME'] == 'Active'))
data_active_inactive_clean = data_clean.loc[mask]

# %%
len(data_clean)
# Out:
# 6047

# %%
data_clean.sort_values(by='Antagonist Efficacy (%)')
# Out:
#                                          PUBCHEM_SMILES  \
# 191       CC1=CC(=CC(=C1O)C)C(C)(C)C2=CC(=C(C(=C2)C)O)C
# 68    C1=CC(=C2C(=C1NCCNCCO)C(=O)C3=C(C=CC(=C3C2=O)O...
# 193   CN1C2=NC(=NC=C2CN(C1=O)C3=CC=CC=C3Br)NC4=CC5=C...
# 347   CC1=C(C(C(=C(N1)C)C(=O)OC/C=C/C2=CC=CC=C2)C3=C...
# 306   C[C@]12CC[C@H]3[C@H]([C@@H]1CC[C@]2(C)O)CC[C@@...
# ...                                                 ...
# 4979  CC(=C)C(=O)OCCC(C(C(C(C(C(F)(F)F)(F)F)(F)F)(F)...
# 4978  CC(CC1=CC=C(C=C1)OCC(=O)O)NCC(C2=CSC(=N2)C(F)(...
# 4977             CCCCC(CC)COC(=O)CCCCC(=O)OCC1=CC=CC=C1
# 4984                                  CC(=CCCC(=C)C=C)C
# 9669                         CN(CCCC(=O)C1=CN=CC=C1)N=O
#
#      PUBCHEM_ACTIVITY_OUTCOME Antagonist Activity       Viability Activity  \
# 191                    Active   active antagonist                 inactive
# 68                     Active   active antagonist        active antagonist
# 193                    Active   active antagonist  inconclusive antagonist
# 347                    Active   active antagonist                 inactive
# 306                    Active   active antagonist                 inactive
# ...                       ...                 ...                      ...
# 4979                 Inactive            inactive                 inactive
# 4978                 Inactive            inactive                 inactive
# 4977                 Inactive            inactive                 inactive
# 4984                 Inactive            inactive                 inactive
# 9669                 Inactive            inactive                 inactive
#
#       Antagonist Efficacy (%)  \
# 191                  -177.383
# 68                   -142.058
# 193                  -135.678
# 347                  -135.491
# 306                  -135.449
# ...                       ...
# 4979                    0.000
# 4978                    0.000
# 4977                    0.000
# 4984                    0.000
# 9669                    0.000
#
#                                               Molecule
# 191   <rdkit.Chem.rdchem.Mol object at 0x7ec597490a50>
# 68    <rdkit.Chem.rdchem.Mol object at 0x7ec5976105f0>
# 193   <rdkit.Chem.rdchem.Mol object at 0x7ec597490ac0>
# 347   <rdkit.Chem.rdchem.Mol object at 0x7ec5974a4120>
# 306   <rdkit.Chem.rdchem.Mol object at 0x7ec597493290>
# ...                                                ...
# 4979  <rdkit.Chem.rdchem.Mol object at 0x7ec597519cb0>
# 4978  <rdkit.Chem.rdchem.Mol object at 0x7ec597519c40>
# 4977  <rdkit.Chem.rdchem.Mol object at 0x7ec597519bd0>
# 4984  <rdkit.Chem.rdchem.Mol object at 0x7ec597519ee0>
# 9669  <rdkit.Chem.rdchem.Mol object at 0x7ec59737bf40>
#
# [6047 rows x 6 columns]

# %% [markdown]
# ## 8. Save the DataSet<a name = 8></a>

# %%
data_clean.to_csv('AID_1259247_final.csv', index=False)

# %%
len(data_clean)
# Out:
# 5135

# %%
data_clean = data_clean.loc[data_clean['Molecule'].notna()]
len(data_clean)
# Out:
# 5134

# %%
PandasTools.WriteSDF(data_clean, "AID_1259247_final.sdf", molColName='Molecule',
                     properties=['PUBCHEM_SMILES', 'PUBCHEM_ACTIVITY_OUTCOME', 'Antagonist Activity',
                                 'Viability Activity', 'Antagonist Efficacy (%)'])
