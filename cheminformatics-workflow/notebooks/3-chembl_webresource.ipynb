# %% [markdown]
# # Chembl webresource client
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Stef0916/chemoinformatics-bioinformatics/blob/main/cheminformatics-workflow/notebooks/3-chembl_webresource.ipynb)

# %% [markdown]
# ## Content
#
# 1. [Import Libraries](#1)
# 2. [Listing all tables](#2)
# 3. [Search for Target Protein](#3)
#     - 3.1 [Select Homo Sapiens Cyclooxygenase-2](#4)
#     - 3.2 [Retrieve Bioactivity Data by IC50](#5)
#     - 3.3 [Remove empty entries](#6)
#     - 3.4 [Remove duplicates](#7)
#     - 3.5 [Manage Std Values Units](#8)
#     - 3.6 [Label: Active, Inactive, Intermediate](#9)
#     - 3.7 [Convert IC50 to pIC50](#10)
# 4. [Molecular Visualization](#11)
# 5. [Sabe DataSet](#12)

# %% [markdown]
# ## ChEMBL Database<a id = 4></a>

# %% [markdown]
# ChEMBL is a database of bioactive molecules with drug-like properties. It brings together chemical, bioactivity, and genomic data to aid the translation of genomic information into effective new drugs. The ChEMBL database contains a vast amount of bioactivity data sourced from scientific literature, specifically focusing on the properties and activities of drug-like molecules. It's a valuable resource for drug discovery and chemical biology research.<sup>[1](https://doi.org/10.1093/nar/gkr777)</sup>

# %% [markdown]
# ## 1. Import Libraries<a name = 1></a>

# %%
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.10/dist-packages (0.10.8)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.1 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.30.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (2023.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)

# %%
# !pip install mols2grid
# Out:
# Requirement already satisfied: mols2grid in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (7.7.1)
# Requirement already satisfied: jinja2>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mols2grid) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mols2grid) (1.5.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.0->mols2grid) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mols2grid) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mols2grid) (2023.3.post1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->mols2grid) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.19.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (21.2.0)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.21)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.4.0
#     Uninstalling attrs-21.4.0:
#       Successfully uninstalled attrs-21.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# requests-cache 0.7.5 requires attrs<22.0,>=21.2, but you have attrs 23.1.0 which is incompatible.
# Successfully installed attrs-23.1.0

# %%
from chembl_webresource_client.new_client import new_client

# %%
import pandas as pd
import numpy as np
import pickle
import stat
import copy

#--------------------------------------------------------------

from rdkit import Chem
from rdkit.Chem import Draw, PandasTools
from rdkit.Chem import PandasTools
import mols2grid

# %%
dir(new_client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'activity',
#  'activity_supplementary_data_by_activity',
#  'assay',
#  'assay_class',
#  'atc_class',
#  'binding_site',
#  'biotherapeutic',
#  'cell_line',
#  'chembl_id_lookup',
#  'compound_record',
#  'compound_structural_alert',
#  'description',
#  'document',
#  'document_similarity',
#  'drug',
#  'drug_indication',
#  'drug_warning',
#  'go_slim',
#  'image',
#  'mechanism',
#  'metabolism',
#  'molecule',
#  'molecule_form',
#  'official',
#  'organism',
#  'protein_classification',
#  'similarity',
#  'source',
#  'substructure',
#  'target',
#  'target_component',
#  'target_relation',
#  'tissue',
#  'xref_source']

# %% [markdown]
# ## 2. Listing all tables<a name = 2></a>

# %%
available_resources = [resource for resource in dir(new_client) if not resource.startswith('_')]
available_resources
# Out:
# ['activity',
#  'activity_supplementary_data_by_activity',
#  'assay',
#  'assay_class',
#  'atc_class',
#  'binding_site',
#  'biotherapeutic',
#  'cell_line',
#  'chembl_id_lookup',
#  'compound_record',
#  'compound_structural_alert',
#  'description',
#  'document',
#  'document_similarity',
#  'drug',
#  'drug_indication',
#  'drug_warning',
#  'go_slim',
#  'image',
#  'mechanism',
#  'metabolism',
#  'molecule',
#  'molecule_form',
#  'official',
#  'organism',
#  'protein_classification',
#  'similarity',
#  'source',
#  'substructure',
#  'target',
#  'target_component',
#  'target_relation',
#  'tissue',
#  'xref_source']

# %% [markdown]
# These resources can be used to query the database for information on drugs, chemical compounds, biological assays, and much more. Each resource corresponds to a different type of data or a different functionality provided by the ChEMBL web API.
#
# For example, to get information about molecules: use `new_client.molecule`.
#
# ```python
# from chembl_webresource_client.new_client import new_client
#
# molecule = new_client.molecule
# mols = molecule.filter(pref_name__iexact='aspirin')
# mols
# ```
#
# More examples:
#
# ```python
# # For targets
# target_resource = new_client.target
# target_results = target_resource.filter(organism__icontains='Homo sapiens')
# target_resource
#
# # For assays
# assay_resource = new_client.assay
# assay_results = assay_resource.filter(assay_type__iexact='B')
# assay_results
#
# # For documents
# document_resource = new_client.document
# document_results = document_resource.filter(journal__icontains='Nature')
# document_results
# ```

# %% [markdown]
# ## 3. Search for Target Protein<a name = 3></a>

# %%
# Target search for Cyclooxygenase-2
target = new_client.target
target_query = target.search('Cyclooxygenase-2')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                        cross_references  \
# 0     [{'xref_id': 'Q8SPQ9', 'xref_name': None, 'xre...
# 1     [{'xref_id': 'P35354', 'xref_name': None, 'xre...
# 2     [{'xref_id': 'O62698', 'xref_name': None, 'xre...
# 3     [{'xref_id': 'Q05769', 'xref_name': None, 'xre...
# 4     [{'xref_id': 'P35355', 'xref_name': None, 'xre...
# ...                                                 ...
# 2842                                                 []
# 2843                                                 []
# 2844                                                 []
# 2845                                                 []
# 2846                                                 []
#
#                     organism                            pref_name  score  \
# 0     Canis lupus familiaris                     Cyclooxygenase-2   23.0
# 1               Homo sapiens                     Cyclooxygenase-2   18.0
# 2                 Bos taurus                     Cyclooxygenase-2   18.0
# 3               Mus musculus                     Cyclooxygenase-2   18.0
# 4          Rattus norvegicus                     Cyclooxygenase-2   18.0
# ...                      ...                                  ...    ...
# 2842            Mus musculus              Glutamate NMDA receptor    0.0
# 2843            Mus musculus               L-type calcium channel    0.0
# 2844       Rattus norvegicus         Voltage-gated sodium channel    0.0
# 2845            Homo sapiens  UDP-glucuronosyltransferases (UGTs)    0.0
# 2846            Mus musculus                     I-kappa-B kinase    0.0
#
#       species_group_flag target_chembl_id  \
# 0                  False       CHEMBL4033
# 1                  False        CHEMBL230
# 2                  False       CHEMBL3331
# 3                  False       CHEMBL4321
# 4                  False       CHEMBL2977
# ...                  ...              ...
# 2842               False    CHEMBL3832634
# 2843               False    CHEMBL3988632
# 2844               False    CHEMBL3988641
# 2845               False    CHEMBL4523985
# 2846               False    CHEMBL4524000
#
#                                       target_components  \
# 0     [{'accession': 'Q8SPQ9', 'component_descriptio...
# 1     [{'accession': 'P35354', 'component_descriptio...
# 2     [{'accession': 'O62698', 'component_descriptio...
# 3     [{'accession': 'Q05769', 'component_descriptio...
# 4     [{'accession': 'P35355', 'component_descriptio...
# ...                                                 ...
# 2842  [{'accession': 'P35436', 'component_descriptio...
# 2843  [{'accession': 'Q01815', 'component_descriptio...
# 2844  [{'accession': 'O88457', 'component_descriptio...
# 2845  [{'accession': 'P22310', 'component_descriptio...
# 2846  [{'accession': 'Q60680', 'component_descriptio...
#
#                 target_type   tax_id
# 0            SINGLE PROTEIN   9615.0
# 1            SINGLE PROTEIN   9606.0
# 2            SINGLE PROTEIN   9913.0
# 3            SINGLE PROTEIN  10090.0
# 4            SINGLE PROTEIN  10116.0
# ...                     ...      ...
# 2842  PROTEIN COMPLEX GROUP  10090.0
# 2843         PROTEIN FAMILY  10090.0
# 2844         PROTEIN FAMILY  10116.0
# 2845         PROTEIN FAMILY   9606.0
# 2846        PROTEIN COMPLEX  10090.0
#
# [2847 rows x 9 columns]

# %%
target_hs = targets.loc[targets['organism'] == 'Homo sapiens']
target_hs.sort_values(by='score', ascending=False)
# Out:
#                                        cross_references      organism  \
# 1     [{'xref_id': 'P35354', 'xref_name': None, 'xre...  Homo sapiens
# 6                                                    []  Homo sapiens
# 9     [{'xref_id': 'P24557', 'xref_name': None, 'xre...  Homo sapiens
# 14                                                   []  Homo sapiens
# 15    [{'xref_id': 'PTGS1', 'xref_name': None, 'xref...  Homo sapiens
# ...                                                 ...           ...
# 2828                                                 []  Homo sapiens
# 2827                                                 []  Homo sapiens
# 2826                                                 []  Homo sapiens
# 2822  [{'xref_id': 'Atrial_natriuretic_peptide', 'xr...  Homo sapiens
# 2845                                                 []  Homo sapiens
#
#                                  pref_name  score  species_group_flag  \
# 1                         Cyclooxygenase-2   18.0               False
# 6                           Cyclooxygenase   15.0               False
# 9                   Thromboxane-A synthase   14.0               False
# 14                             COX-1/COX-2   14.0               False
# 15                        Cyclooxygenase-1   13.0               False
# ...                                    ...    ...                 ...
# 2828  Inhibitor of NF-kappa-B kinase (IKK)    0.0               False
# 2827             Serotonin (5-HT) receptor    0.0               False
# 2826                 Alcohol dehydrogenase    0.0               False
# 2822             Atrial natriuretic factor    0.0               False
# 2845   UDP-glucuronosyltransferases (UGTs)    0.0               False
#
#      target_chembl_id                                  target_components  \
# 1           CHEMBL230  [{'accession': 'P35354', 'component_descriptio...
# 6       CHEMBL2094253  [{'accession': 'P35354', 'component_descriptio...
# 9          CHEMBL1835  [{'accession': 'P24557', 'component_descriptio...
# 14      CHEMBL4523964  [{'accession': 'P35354', 'component_descriptio...
# 15          CHEMBL221  [{'accession': 'P23219', 'component_descriptio...
# ...               ...                                                ...
# 2828    CHEMBL2111328  [{'accession': 'O14920', 'component_descriptio...
# 2827    CHEMBL2096904  [{'accession': 'P30939', 'component_descriptio...
# 2826    CHEMBL2096668  [{'accession': 'P07327', 'component_descriptio...
# 2822    CHEMBL1293193  [{'accession': 'P01160', 'component_descriptio...
# 2845    CHEMBL4523985  [{'accession': 'P22310', 'component_descriptio...
#
#             target_type  tax_id
# 1        SINGLE PROTEIN  9606.0
# 6        PROTEIN FAMILY  9606.0
# 9        SINGLE PROTEIN  9606.0
# 14    SELECTIVITY GROUP  9606.0
# 15       SINGLE PROTEIN  9606.0
# ...                 ...     ...
# 2828    PROTEIN COMPLEX  9606.0
# 2827     PROTEIN FAMILY  9606.0
# 2826     PROTEIN FAMILY  9606.0
# 2822     SINGLE PROTEIN  9606.0
# 2845     PROTEIN FAMILY  9606.0
#
# [1681 rows x 9 columns]

# %% [markdown]
# - **cross_references**: Contains cross-reference IDs for the target proteins.
# - **organism**: The organism from which the target protein originates.
# - **pref_name**: The preferred name of the target protein.
# - **score**: A numerical score associated with the target protein indicating relevance.
# - **species_group_flag**: A boolean flag indicating if the target is a species group.
# - **target_chembl_id**: The unique ChEMBL ID for the target protein.
# - **target_components**: Contains accession numbers and descriptions of target components.
# - **target_type**: Type of the target (e.g., SINGLE PROTEIN, SELECTIVITY GROUP).
# - **tax_id**: Taxonomy ID for the organism.

# %% [markdown]
# ### 3.1 Select Homo Sapiens Cyclooxygenase-2<a name = 4></a>

# %%
selected_target = target_hs.target_chembl_id.iloc[0]
selected_target
# Out:
# 'CHEMBL230'

# %% [markdown]
# ### 3.2 Retrieve Bioactivity Data filtered by IC50<a name = 5></a>

# %%
activity = new_client.activity
bioactivities = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
activity_df = pd.DataFrame.from_dict(bioactivities)
activity_df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 7499                                               None             None
# 7500  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 7501  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 7502  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 7503  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           34205                                                 []
# 1           34209                                                 []
# 2           35476                                                 []
# 3           36218                                                 []
# 4           36708                                                 []
# ...           ...                                                ...
# 7499     24957364  [{'comments': None, 'relation': '=', 'result_f...
# 7500     24969909  [{'comments': None, 'relation': '=', 'result_f...
# 7501     24969910  [{'comments': None, 'relation': '=', 'result_f...
# 7502     24969911  [{'comments': None, 'relation': '=', 'result_f...
# 7503     24969912  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL762912  In vitro inhibitory activity against human pro...
# 1       CHEMBL762912  In vitro inhibitory activity against human pro...
# 2       CHEMBL762912  In vitro inhibitory activity against human pro...
# 3       CHEMBL769655  Tested in vitro for inhibition against Prostag...
# 4       CHEMBL762912  In vitro inhibitory activity against human pro...
# ...              ...                                                ...
# 7499   CHEMBL5214216  Selectivity interaction (NIBR principial panel...
# 7500   CHEMBL5217865  Inhibition of COX2 (unknown origin) assessed a...
# 7501   CHEMBL5217865  Inhibition of COX2 (unknown origin) assessed a...
# 7502   CHEMBL5217865  Inhibition of COX2 (unknown origin) assessed a...
# 7503   CHEMBL5217865  Inhibition of COX2 (unknown origin) assessed a...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 7499          B                    None                   None  BAO_0000190
# 7500          B                    None                   None  BAO_0000190
# 7501          B                    None                   None  BAO_0000190
# 7502          B                    None                   None  BAO_0000190
# 7503          B                    None                   None  BAO_0000190
#
#       ... target_organism  target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 1     ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 2     ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 3     ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 4     ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# ...   ...             ...               ...           ...        ...   ...
# 7499  ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 7500  ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 7501  ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 7502  ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
# 7503  ...    Homo sapiens  Cyclooxygenase-2          9606       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    uM  UO_0000065        None   0.06
# 1     IC50    uM  UO_0000065        None   3.23
# 2     IC50    uM  UO_0000065        None   0.08
# 3     IC50    nM  UO_0000065        None   0.12
# 4     IC50    uM  UO_0000065        None  100.0
# ...    ...   ...         ...         ...    ...
# 7499  IC50    µM        None        None    0.8
# 7500  IC50    uM  UO_0000065        None   3.76
# 7501  IC50    uM  UO_0000065        None   2.29
# 7502  IC50    uM  UO_0000065        None   1.93
# 7503  IC50    uM  UO_0000065        None   1.79
#
# [7504 rows x 46 columns]

# %%
activity_df.columns
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
# Columns to keep
columns_to_keep = ['canonical_smiles', 'molecule_chembl_id', 'parent_molecule_chembl_id',
                   'pchembl_value', 'standard_value', 'standard_relation', 'standard_units', 'standard_type',
                   'target_chembl_id', 'target_pref_name', 'molecule_pref_name', 'units']

# Dropping all other columns
activity_df = activity_df.loc[:, columns_to_keep]

# %%
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7499  Cc1c(Nc2ccc(S(=O)(=O)N3CCN(C)CC3)cc2F)nc2ccc(N...      CHEMBL4758581
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
# 7503                         CC(C)Cc1ccc(C(C)C(=O)O)cc1          CHEMBL521
#
#      parent_molecule_chembl_id pchembl_value standard_value standard_relation  \
# 0                 CHEMBL297008          7.22           60.0                 =
# 1                 CHEMBL289813          5.49         3230.0                 =
# 2                  CHEMBL43736          7.10           80.0                 =
# 3                 CHEMBL140167          9.92           0.12                 =
# 4                  CHEMBL44194          None       100000.0                 >
# ...                        ...           ...            ...               ...
# 7499             CHEMBL4758581          None            0.8                 =
# 7500             CHEMBL5220891          5.42         3760.0                 =
# 7501             CHEMBL5219013          5.64         2290.0                 =
# 7502             CHEMBL5219227          5.71         1930.0                 =
# 7503                 CHEMBL521          5.75         1790.0                 =
#
#      standard_units standard_type target_chembl_id  target_pref_name  \
# 0                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 1                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 2                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 4                nM          IC50        CHEMBL230  Cyclooxygenase-2
# ...             ...           ...              ...               ...
# 7499             µM          IC50        CHEMBL230  Cyclooxygenase-2
# 7500             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7501             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7502             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7503             nM          IC50        CHEMBL230  Cyclooxygenase-2
#
#      molecule_pref_name units
# 0                  None    uM
# 1                  None    uM
# 2                  None    uM
# 3                  None    nM
# 4                  None    uM
# ...                 ...   ...
# 7499               None    µM
# 7500               None    uM
# 7501               None    uM
# 7502               None    uM
# 7503          IBUPROFEN    uM
#
# [7504 rows x 12 columns]

# %% [markdown]
# ### 3.3 Remove Empty entries<a name = 6></a>

# %%
empty_smiles = activity_df.loc[activity_df['canonical_smiles'].isna(), :]
len(empty_smiles)
# Out:
# 33

# %%
empty_smiles
# Out:
#      canonical_smiles molecule_chembl_id parent_molecule_chembl_id  \
# 4009             None         CHEMBL1366                CHEMBL1366
# 4024             None      CHEMBL1476898             CHEMBL1476898
# 4035             None      CHEMBL1458880             CHEMBL1458880
# 4199             None       CHEMBL306043              CHEMBL306043
# 4216             None      CHEMBL1201469             CHEMBL1201469
# 4230             None      CHEMBL1200431             CHEMBL1200431
# 4251             None      CHEMBL1909056             CHEMBL1909056
# 4291             None        CHEMBL11359             CHEMBL2068237
# 4312             None         CHEMBL1351                CHEMBL1351
# 4316             None      CHEMBL1909057             CHEMBL1909057
# 4328             None      CHEMBL1909054             CHEMBL1909054
# 4365             None      CHEMBL1909055             CHEMBL1909055
# 4380             None      CHEMBL1200528             CHEMBL1200528
# 4390             None      CHEMBL1909071             CHEMBL1909071
# 4414             None       CHEMBL414804              CHEMBL414804
# 4420             None      CHEMBL1909075             CHEMBL1909075
# 4466             None      CHEMBL3559671             CHEMBL3559671
# 4482             None      CHEMBL2108139             CHEMBL2108139
# 4526             None      CHEMBL1909064             CHEMBL1909064
# 4527             None      CHEMBL1909067             CHEMBL1909067
# 4544             None      CHEMBL1909068             CHEMBL1909068
# 4558             None      CHEMBL1909062             CHEMBL1909062
# 4561             None      CHEMBL1909069             CHEMBL1909069
# 4574             None      CHEMBL1909063             CHEMBL1909063
# 4615             None      CHEMBL1201631             CHEMBL1201631
# 4618             None      CHEMBL1200693             CHEMBL1200693
# 4673             None         CHEMBL1386                CHEMBL1386
# 4683             None      CHEMBL1909083             CHEMBL1909083
# 4709             None      CHEMBL1909079             CHEMBL1909079
# 4721             None       CHEMBL136478             CHEMBL2097081
# 4737             None       CHEMBL179166              CHEMBL179166
# 4778             None       CHEMBL508338              CHEMBL508338
# 6733             None      CHEMBL4527106             CHEMBL4527106
#
#      pchembl_value standard_value standard_relation standard_units  \
# 4009          None           None              None           None
# 4024          None           None              None           None
# 4035          None           None              None           None
# 4199          None           None              None           None
# 4216          None           None              None           None
# 4230          None           None              None           None
# 4251          None           None              None           None
# 4291          None           None              None           None
# 4312          None           None              None           None
# 4316          None           None              None           None
# 4328          None           None              None           None
# 4365          None           None              None           None
# 4380          None           None              None           None
# 4390          None           None              None           None
# 4414          None           None              None           None
# 4420          None           None              None           None
# 4466          None           None              None           None
# 4482          None           None              None           None
# 4526          None           None              None           None
# 4527          None           None              None           None
# 4544          None           None              None           None
# 4558          None           None              None           None
# 4561          None           None              None           None
# 4574          None           None              None           None
# 4615          None           None              None           None
# 4618          None           None              None           None
# 4673          None           None              None           None
# 4683          None           None              None           None
# 4709          None           None              None           None
# 4721          None           None              None           None
# 4737          None           None              None           None
# 4778          None           None              None           None
# 6733          7.22           60.0                 =             nM
#
#      standard_type target_chembl_id  target_pref_name  \
# 4009          IC50        CHEMBL230  Cyclooxygenase-2
# 4024          IC50        CHEMBL230  Cyclooxygenase-2
# 4035          IC50        CHEMBL230  Cyclooxygenase-2
# 4199          IC50        CHEMBL230  Cyclooxygenase-2
# 4216          IC50        CHEMBL230  Cyclooxygenase-2
# 4230          IC50        CHEMBL230  Cyclooxygenase-2
# 4251          IC50        CHEMBL230  Cyclooxygenase-2
# 4291          IC50        CHEMBL230  Cyclooxygenase-2
# 4312          IC50        CHEMBL230  Cyclooxygenase-2
# 4316          IC50        CHEMBL230  Cyclooxygenase-2
# 4328          IC50        CHEMBL230  Cyclooxygenase-2
# 4365          IC50        CHEMBL230  Cyclooxygenase-2
# 4380          IC50        CHEMBL230  Cyclooxygenase-2
# 4390          IC50        CHEMBL230  Cyclooxygenase-2
# 4414          IC50        CHEMBL230  Cyclooxygenase-2
# 4420          IC50        CHEMBL230  Cyclooxygenase-2
# 4466          IC50        CHEMBL230  Cyclooxygenase-2
# 4482          IC50        CHEMBL230  Cyclooxygenase-2
# 4526          IC50        CHEMBL230  Cyclooxygenase-2
# 4527          IC50        CHEMBL230  Cyclooxygenase-2
# 4544          IC50        CHEMBL230  Cyclooxygenase-2
# 4558          IC50        CHEMBL230  Cyclooxygenase-2
# 4561          IC50        CHEMBL230  Cyclooxygenase-2
# 4574          IC50        CHEMBL230  Cyclooxygenase-2
# 4615          IC50        CHEMBL230  Cyclooxygenase-2
# 4618          IC50        CHEMBL230  Cyclooxygenase-2
# 4673          IC50        CHEMBL230  Cyclooxygenase-2
# 4683          IC50        CHEMBL230  Cyclooxygenase-2
# 4709          IC50        CHEMBL230  Cyclooxygenase-2
# 4721          IC50        CHEMBL230  Cyclooxygenase-2
# 4737          IC50        CHEMBL230  Cyclooxygenase-2
# 4778          IC50        CHEMBL230  Cyclooxygenase-2
# 6733          IC50        CHEMBL230  Cyclooxygenase-2
#
#                      molecule_pref_name units
# 4009                          AURANOFIN  None
# 4024                    CADMIUM ACETATE  None
# 4035                 CADMIUM DICHLORIDE  None
# 4199             GOLD SODIUM THIOMALATE  None
# 4216                         GRAMICIDIN  None
# 4230          GADOPENTETATE DIMEGLUMINE  None
# 4251         COBALT(II) ACETYLACETONATE  None
# 4291                          CISPLATIN  None
# 4312                        CARBOPLATIN  None
# 4316                   COPPER(II) OXIDE  None
# 4328             CARBOXYMETHYLCELLULOSE  None
# 4365                 COBALTOUS CHLORIDE  None
# 4380                   CHROMIC CHLORIDE  None
# 4390                               None  None
# 4414                        OXALIPLATIN  None
# 4420                               None  None
# 4466                  POLYVINYL ALCOHOL  None
# 4482                           POVIDONE  None
# 4526  LIPOPOLYSACCHARIDE E. COLI O55:B5  None
# 4527                               None  None
# 4544                               None  None
# 4558                  LEAD (II) ACETATE  None
# 4561                               None  None
# 4574                   LEAD(IV) ACETATE  None
# 4615                            INSULIN  None
# 4618                 MANGANESE CHLORIDE  None
# 4673                        TRANSPLATIN  None
# 4683             ZIRCONIUM(IV) CHLORIDE  None
# 4709                  STANNOUS FLUORIDE  None
# 4721               SODIUM NITROPRUSSIDE  None
# 4737                  SODIUM ORTHOVANAD  None
# 4778                         THIMEROSAL  None
# 6733                               None    uM

# %%
len(activity_df)
# Out:
# 7504

# %%
activity_df = activity_df.loc[activity_df['canonical_smiles'].notna()]
len(activity_df)
# Out:
# 7471

# %%
empty_std_val = activity_df.loc[activity_df['standard_value'].isna()]
len(empty_std_val)
# Out:
# 969

# %%
empty_std_val
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 6              COC(=O)c1ccc(-n2c(C)ccc2-c2ccc(F)cc2)cc1        CHEMBL44464
# 13       CCN(CC)OC(=O)c1ccc(-n2c(C)ccc2-c2ccc(F)cc2)cc1       CHEMBL290608
# 23         Cc1ccc(-c2ccc(F)cc2)n1-c1ccc([S+](C)[O-])cc1        CHEMBL40891
# 33              CC(=O)c1ccc(-n2c(C)ccc2-c2ccc(F)cc2)cc1       CHEMBL442349
# 41             COc1ccc(-c2ccc(C)n2-c2ccc(C(C)=O)cc2)cc1       CHEMBL298079
# ...                                                 ...                ...
# 7014                  CC[C@H](C(=O)O)c1ccc2cc(OC)ccc2c1      CHEMBL4466610
# 7121                        CC(c1cc2ccccc2s1)N(O)C(N)=O           CHEMBL93
# 7372                      COc1ccc2[nH]cc(CCNC(C)=O)c2c1           CHEMBL45
# 7428  CC[C@@]1(O)C(=O)OCc2c1cc1n(c2=O)Cc2cc3c(CN(C)C...           CHEMBL84
# 7438                        CC(c1cc2ccccc2s1)N(O)C(N)=O           CHEMBL93
#
#      parent_molecule_chembl_id pchembl_value standard_value standard_relation  \
# 6                  CHEMBL44464          None           None              None
# 13                CHEMBL290608          None           None              None
# 23                 CHEMBL40891          None           None              None
# 33                CHEMBL442349          None           None              None
# 41                CHEMBL298079          None           None              None
# ...                        ...           ...            ...               ...
# 7014             CHEMBL4466610          None           None              None
# 7121                  CHEMBL93          None           None              None
# 7372                  CHEMBL45          None           None              None
# 7428                  CHEMBL84          None           None              None
# 7438                  CHEMBL93          None           None              None
#
#      standard_units standard_type target_chembl_id  target_pref_name  \
# 6                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 13               nM          IC50        CHEMBL230  Cyclooxygenase-2
# 23               nM          IC50        CHEMBL230  Cyclooxygenase-2
# 33               nM          IC50        CHEMBL230  Cyclooxygenase-2
# 41               nM          IC50        CHEMBL230  Cyclooxygenase-2
# ...             ...           ...              ...               ...
# 7014           None          IC50        CHEMBL230  Cyclooxygenase-2
# 7121           None          IC50        CHEMBL230  Cyclooxygenase-2
# 7372           None          IC50        CHEMBL230  Cyclooxygenase-2
# 7428           None          IC50        CHEMBL230  Cyclooxygenase-2
# 7438           None          IC50        CHEMBL230  Cyclooxygenase-2
#
#      molecule_pref_name units
# 6                  None    uM
# 13                 None    uM
# 23                 None    uM
# 33                 None    uM
# 41                 None    uM
# ...                 ...   ...
# 7014               None  None
# 7121           ZILEUTON  None
# 7372          MELATONIN  None
# 7428          TOPOTECAN  None
# 7438           ZILEUTON  None
#
# [969 rows x 12 columns]

# %%
activity_df = activity_df.loc[activity_df['standard_value'].notna()]
len(activity_df)
# Out:
# 6502

# %%
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7499  Cc1c(Nc2ccc(S(=O)(=O)N3CCN(C)CC3)cc2F)nc2ccc(N...      CHEMBL4758581
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
# 7503                         CC(C)Cc1ccc(C(C)C(=O)O)cc1          CHEMBL521
#
#      parent_molecule_chembl_id pchembl_value standard_value standard_relation  \
# 0                 CHEMBL297008          7.22           60.0                 =
# 1                 CHEMBL289813          5.49         3230.0                 =
# 2                  CHEMBL43736          7.10           80.0                 =
# 3                 CHEMBL140167          9.92           0.12                 =
# 4                  CHEMBL44194          None       100000.0                 >
# ...                        ...           ...            ...               ...
# 7499             CHEMBL4758581          None            0.8                 =
# 7500             CHEMBL5220891          5.42         3760.0                 =
# 7501             CHEMBL5219013          5.64         2290.0                 =
# 7502             CHEMBL5219227          5.71         1930.0                 =
# 7503                 CHEMBL521          5.75         1790.0                 =
#
#      standard_units standard_type target_chembl_id  target_pref_name  \
# 0                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 1                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 2                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3                nM          IC50        CHEMBL230  Cyclooxygenase-2
# 4                nM          IC50        CHEMBL230  Cyclooxygenase-2
# ...             ...           ...              ...               ...
# 7499             µM          IC50        CHEMBL230  Cyclooxygenase-2
# 7500             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7501             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7502             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 7503             nM          IC50        CHEMBL230  Cyclooxygenase-2
#
#      molecule_pref_name units
# 0                  None    uM
# 1                  None    uM
# 2                  None    uM
# 3                  None    nM
# 4                  None    uM
# ...                 ...   ...
# 7499               None    µM
# 7500               None    uM
# 7501               None    uM
# 7502               None    uM
# 7503          IBUPROFEN    uM
#
# [6502 rows x 12 columns]

# %% [markdown]
# ### 3.4 Remove Duplicates<a name = 7></a>

# %%
len(activity_df['canonical_smiles'].unique())
# Out:
# 4733

# %%
smiles_dupl = activity_df.loc[activity_df['canonical_smiles'].duplicated()]
smiles_dupl.sort_values(by='canonical_smiles')
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 3889                  Brc1ccc(Oc2ccc(OCCN3CCCC3)cc2)cc1      CHEMBL1775104
# 1991         C#CCCCC(=O)c1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1        CHEMBL13878
# 2355         C#CCCCC(=O)c1cc(C(C)(C)C)c(O)c(C(C)(C)C)c1        CHEMBL13878
# 1986         C#CCCCC(=O)c1cc(C(C)(C)C)c2c(c1)C(C)(C)CO2        CHEMBL13920
# 6019  C#Cc1cccc(Nc2ncnc3cc(OCCOC(=O)C(C)c4ccc5cc(OC)...      CHEMBL3740850
# ...                                                 ...                ...
# 6042                     Oc1ccc(/C=C/c2cc(O)cc(O)c2)cc1          CHEMBL165
# 3877                    c1cc(Oc2ccc(OCCN3CCCC3)cc2)ccn1      CHEMBL1775092
# 3871                    c1ccc(Oc2ccc(OCCN3CCCC3)cc2)cc1       CHEMBL162424
# 3876                    c1ccc(Oc2ccc(OCCN3CCCC3)cc2)nc1      CHEMBL1775091
# 3882                    c1cnc(Oc2ccc(OCCN3CCCC3)cc2)cn1      CHEMBL1775097
#
#      parent_molecule_chembl_id pchembl_value standard_value standard_relation  \
# 3889             CHEMBL1775104          5.29         5100.0                 =
# 1991               CHEMBL13878          7.00          100.0                 =
# 2355               CHEMBL13878          7.00          100.0                 =
# 1986               CHEMBL13920          7.82           15.0                 =
# 6019             CHEMBL3740850          4.64        23000.0                 =
# ...                        ...           ...            ...               ...
# 6042                 CHEMBL165          6.00          996.0                 =
# 3877             CHEMBL1775092          None       100000.0                 >
# 3871              CHEMBL162424          None       100000.0                 >
# 3876             CHEMBL1775091          None       100000.0                 >
# 3882             CHEMBL1775097          None       100000.0                 >
#
#      standard_units standard_type target_chembl_id  target_pref_name  \
# 3889             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 1991             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 2355             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 1986             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 6019             nM          IC50        CHEMBL230  Cyclooxygenase-2
# ...             ...           ...              ...               ...
# 6042             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3877             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3871             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3876             nM          IC50        CHEMBL230  Cyclooxygenase-2
# 3882             nM          IC50        CHEMBL230  Cyclooxygenase-2
#
#      molecule_pref_name units
# 3889               None    uM
# 1991         TEBUFELONE    uM
# 2355         TEBUFELONE    uM
# 1986               None    uM
# 6019               None    uM
# ...                 ...   ...
# 6042        RESVERATROL    uM
# 3877               None    uM
# 3871               None    uM
# 3876               None    uM
# 3882               None    uM
#
# [1769 rows x 12 columns]

# %%
activity_df = activity_df.loc[~activity_df['canonical_smiles'].duplicated()]
len(activity_df)
# Out:
# 4733

# %%
activity_df = activity_df[['canonical_smiles', 'molecule_chembl_id', 'standard_value', 'standard_units', 'standard_type']]
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7498              O=c1[nH]cc(CSc2ccc(C(F)F)cc2)[nH]c1=O      CHEMBL5191702
# 7499  Cc1c(Nc2ccc(S(=O)(=O)N3CCN(C)CC3)cc2F)nc2ccc(N...      CHEMBL4758581
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
#
#      standard_value standard_units standard_type
# 0              60.0             nM          IC50
# 1            3230.0             nM          IC50
# 2              80.0             nM          IC50
# 3              0.12             nM          IC50
# 4          100000.0             nM          IC50
# ...             ...            ...           ...
# 7498        10000.0             nM          IC50
# 7499            0.8             µM          IC50
# 7500         3760.0             nM          IC50
# 7501         2290.0             nM          IC50
# 7502         1930.0             nM          IC50
#
# [4733 rows x 5 columns]

# %% [markdown]
# ### 3.5 Manage Standard Value Units<a name = 8></a>

# %%
activity_df.loc[activity_df['standard_units'] != 'nM']
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 3023  C=C[C@@H]1[C@@H](O)C[C@@H]2[C@]3(CC[C@]4(C)[C@...       CHEMBL479210
# 3117            O=c1cc(-c2ccc(O)c(O)c2)oc2cc(O)cc(O)c12          CHEMBL151
# 3129            COc1cc2oc(-c3ccc(O)cc3)cc(=O)c2c(O)c1OC       CHEMBL348436
# 3221  COc1cc(C(O)C(COC(=O)/C=C/c2ccc(O)cc2)Oc2c(OC)c...       CHEMBL501943
# 3222  COc1cc(C(O)C(COC(=O)/C=C/c2ccc(O)cc2)Oc2ccc(/C...       CHEMBL455027
# 3223  C[C@@H]1O[C@@H](O[C@@H]2Cc3c(O)cc(O)cc3O[C@@H]...       CHEMBL517484
# 3228  COC(=O)[C@@H](c1ccccc1)[C@H](C1=C(O)/C(=C/c2cc...       CHEMBL463211
# 3270  C=C(CC[C@@H](C)[C@H]1CC[C@H]2[C@@H]3CC=C4C(=O)...       CHEMBL470866
# 7329    Cc1ccc2oc(=O)cc(CSc3nnc(CSc4nc5ccccc5o4)o3)c2c1      CHEMBL4856182
# 7330   COc1ccc2oc(=O)cc(CSc3nnc(CSc4nc5ccccc5o4)o3)c2c1      CHEMBL4868808
# 7331  O=c1cc(CSc2nnc(CSc3nc4ccccc4o3)o2)c2c(ccc3cccc...      CHEMBL4856194
# 7332  O=c1cc(CSc2nnc(CSc3nc4ccccc4o3)o2)c2ccc3ccccc3...      CHEMBL4855962
# 7333    Cc1ccc2c(CSc3nnc(CSc4nc5ccccc5o4)o3)cc(=O)oc2c1      CHEMBL4871667
# 7334  Cc1cc(C)c2c(CSc3nnc(CSc4nc5ccccc5o4)o3)cc(=O)o...      CHEMBL4846345
# 7335  Cc1cccc2oc(=O)cc(CSc3nnc(CSc4nc5cc(Cl)ccc5o4)o...      CHEMBL4879127
# 7336  COc1ccc2oc(=O)cc(CSc3nnc(CSc4nc5cc(Cl)ccc5o4)o...      CHEMBL4868438
# 7337  O=c1cc(CSc2nnc(CSc3nc4cc(Cl)ccc4o3)o2)c2c(ccc3...      CHEMBL4858695
# 7338  O=c1cc(CSc2nnc(CSc3nc4cc(Cl)ccc4o3)o2)c2ccc3cc...      CHEMBL4864874
# 7339  Cc1ccc2c(CSc3nnc(CSc4nc5cc(Cl)ccc5o4)o3)cc(=O)...      CHEMBL4869860
# 7340  Cc1cc(C)c2c(CSc3nnc(CSc4nc5cc(Cl)ccc5o4)o3)cc(...      CHEMBL4867901
# 7429  Cc1cn([C@H](C)CC#N)c(=O)c2cc(Cn3nc(C(F)F)cc3Cl...      CHEMBL5092058
# 7499  Cc1c(Nc2ccc(S(=O)(=O)N3CCN(C)CC3)cc2F)nc2ccc(N...      CHEMBL4758581
#
#      standard_value standard_units standard_type
# 3023            4.7             ug          IC50
# 3117          100.0        ug.mL-1          IC50
# 3129            6.0              %          IC50
# 3221          100.0        ug.mL-1          IC50
# 3222          100.0        ug.mL-1          IC50
# 3223          100.0        ug.mL-1          IC50
# 3228          100.0        ug.mL-1          IC50
# 3270           10.0        ug.mL-1          IC50
# 7329          19.95        ug.mL-1          IC50
# 7330          32.93        ug.mL-1          IC50
# 7331          24.59        ug.mL-1          IC50
# 7332          12.82        ug.mL-1          IC50
# 7333          23.74        ug.mL-1          IC50
# 7334          25.02        ug.mL-1          IC50
# 7335          54.42        ug.mL-1          IC50
# 7336          44.54        ug.mL-1          IC50
# 7337           17.7        ug.mL-1          IC50
# 7338          11.35        ug.mL-1          IC50
# 7339          13.67        ug.mL-1          IC50
# 7340          13.23        ug.mL-1          IC50
# 7429           10.0             µM          IC50
# 7499            0.8             µM          IC50

# %%
len(activity_df.loc[activity_df['standard_units'] != 'nM'])
# Out:
# 22

# %%
activity_df = activity_df[activity_df['standard_units'] == 'nM']
len(activity_df)
# Out:
# 4711

# %% [markdown]
# ### 3.6 Label: Active, Inactive, Intermediate<a name = 9></a>

# %%
activity_df['standard_value'].describe()
# Out:
# count         4711
# unique        1470
# top       100000.0
# freq           368
# Name: standard_value, dtype: object

# %%
activity_df = activity_df.copy()
activity_df['standard_value'] = activity_df['standard_value'].astype('float64')

# %%
activity_df['standard_value'].describe()
# Out:
# count    4.711000e+03
# mean     5.641769e+04
# std      1.003254e+06
# min      0.000000e+00
# 25%      1.700000e+02
# 50%      2.000000e+03
# 75%      1.616500e+04
# max      6.000000e+07
# Name: standard_value, dtype: float64

# %%
bio_class = []

for i in activity_df['standard_value']:
    if i >= 10000:
        bio_class.append('active')
    elif i >= 1000:
        bio_class.append('intermediate')
    else:
        bio_class.append('inactive')

# %%
activity_df['class'] = bio_class

# %%
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7497           O=c1[nH]cc(CSc2ccc(C(F)(F)F)cc2)[nH]c1=O      CHEMBL5178658
# 7498              O=c1[nH]cc(CSc2ccc(C(F)F)cc2)[nH]c1=O      CHEMBL5191702
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
#
#       standard_value standard_units standard_type         class
# 0              60.00             nM          IC50      inactive
# 1            3230.00             nM          IC50  intermediate
# 2              80.00             nM          IC50      inactive
# 3               0.12             nM          IC50      inactive
# 4          100000.00             nM          IC50        active
# ...              ...            ...           ...           ...
# 7497        10000.00             nM          IC50        active
# 7498        10000.00             nM          IC50        active
# 7500         3760.00             nM          IC50  intermediate
# 7501         2290.00             nM          IC50  intermediate
# 7502         1930.00             nM          IC50  intermediate
#
# [4711 rows x 6 columns]

# %% [markdown]
# ### 3.7 Convert IC50 to pIC50<a name = 10></a>

# %%
# Replace 0 with a small value (e.g., 1 nM) to avoid log(0)
activity_df['standard_value'] = activity_df['standard_value'].replace(0,1)

# %%
pIC50 = []

for std_values in activity_df['standard_value']:
    molar = std_values*(10**-9)
    pIC50.append(-np.log10(molar))

# %%
pIC50[:10]
# Out:
# [7.221848749616356,
#  5.490797477668897,
#  7.096910013008056,
#  9.920818753952375,
#  4.0,
#  5.79317412396815,
#  4.0,
#  4.0,
#  4.0,
#  4.0]

# %%
activity_df['pIC50'] = pIC50
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7497           O=c1[nH]cc(CSc2ccc(C(F)(F)F)cc2)[nH]c1=O      CHEMBL5178658
# 7498              O=c1[nH]cc(CSc2ccc(C(F)F)cc2)[nH]c1=O      CHEMBL5191702
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
#
#       standard_value standard_units standard_type         class     pIC50
# 0              60.00             nM          IC50      inactive  7.221849
# 1            3230.00             nM          IC50  intermediate  5.490797
# 2              80.00             nM          IC50      inactive  7.096910
# 3               0.12             nM          IC50      inactive  9.920819
# 4          100000.00             nM          IC50        active  4.000000
# ...              ...            ...           ...           ...       ...
# 7497        10000.00             nM          IC50        active  5.000000
# 7498        10000.00             nM          IC50        active  5.000000
# 7500         3760.00             nM          IC50  intermediate  5.424812
# 7501         2290.00             nM          IC50  intermediate  5.640165
# 7502         1930.00             nM          IC50  intermediate  5.714443
#
# [4711 rows x 7 columns]

# %%
activity_df.drop(['standard_value', 'standard_units', 'standard_type'], axis=1, inplace=True)

# %%
activity_df
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 0              Cc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccccc1       CHEMBL297008
# 1      Cc1c(C=O)cc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1       CHEMBL289813
# 2     Cc1c(COc2cccc(Cl)c2)cc(-c2ccc(S(C)(=O)=O)cc2)n...        CHEMBL43736
# 3        Fc1ccc(-c2[nH]c(-c3ccc(F)cc3)c3c2C2CCC3CC2)cc1       CHEMBL140167
# 4          CCc1ccc(-c2ccc(S(C)(=O)=O)cc2)n1-c1ccc(F)cc1        CHEMBL44194
# ...                                                 ...                ...
# 7497           O=c1[nH]cc(CSc2ccc(C(F)(F)F)cc2)[nH]c1=O      CHEMBL5178658
# 7498              O=c1[nH]cc(CSc2ccc(C(F)F)cc2)[nH]c1=O      CHEMBL5191702
# 7500  C[C@H](C(=O)OC(Cn1ccnc1)c1ccc(F)cc1)c1ccc(-c2c...      CHEMBL5220891
# 7501  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1)c1...      CHEMBL5219013
# 7502  C[C@H](C(=O)N(C)CC(O)(Cn1ccnc1)c1ccc(Cl)cc1Cl)...      CHEMBL5219227
#
#              class     pIC50
# 0         inactive  7.221849
# 1     intermediate  5.490797
# 2         inactive  7.096910
# 3         inactive  9.920819
# 4           active  4.000000
# ...            ...       ...
# 7497        active  5.000000
# 7498        active  5.000000
# 7500  intermediate  5.424812
# 7501  intermediate  5.640165
# 7502  intermediate  5.714443
#
# [4711 rows x 4 columns]

# %% [markdown]
# ## 4. Molecules Visualization<a name = 11></a>

# %%
activity_df['Molecules'] = activity_df['canonical_smiles'].apply(lambda x: Chem.MolFromSmiles(x))

# %%
activity_df.sort_values(by='pIC50', ascending=False)
# Out:
#                                        canonical_smiles molecule_chembl_id  \
# 3044  COc1ccc(-c2c(-c3ccc(S(N)(=O)=O)cc3)[nH]c3ccccc...       CHEMBL499068
# 7481  [11CH3]Oc1ccc(-c2c(-c3ccc(S(N)(=O)=O)cc3)[nH]c...      CHEMBL5196097
# 3043  COc1ccc(-c2c(-c3ccc(S(C)(=O)=O)cc3)[nH]c3ccccc...       CHEMBL499069
# 3047  CS(=O)(=O)c1ccc(-c2[nH]c3ccccc3c2-c2ccc(F)cc2)cc1       CHEMBL501208
# 3049  Cc1ccc2[nH]c(-c3ccc(S(N)(=O)=O)cc3)c(-c3ccccc3...       CHEMBL525247
# ...                                                 ...                ...
# 2359    CS(=O)(=O)c1ccc(-c2occ(Cl)c(=O)c2-c2ccccc2F)cc1       CHEMBL309156
# 2365  COc1ccc(-c2c(-c3ccc(S(C)(=O)=O)cc3)occ(Cl)c2=O...        CHEMBL69683
# 2369     CS(=O)(=O)c1ccc(-c2occ(Cl)c(=O)c2-c2cccnc2)cc1        CHEMBL69030
# 5212  CS(=O)(=O)c1ccc(-c2nc(NC3CC=CCC3)cc(C(F)(F)F)n...      CHEMBL2234864
# 3137          Oc1cc(O)c2cc(O)c(-c3ccc(O)c(O)c3)[o+]c2c1       CHEMBL404515
#
#          class      pIC50                                         Molecules
# 3044  inactive  11.221849  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d74900>
# 7481  inactive  11.221849  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0bc19a0>
# 3043  inactive  10.698970  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d74890>
# 3047  inactive  10.698970  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d74a50>
# 3049  inactive  10.698970  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d74b30>
# ...        ...        ...                                               ...
# 2359    active   2.200000  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d68120>
# 2365    active   2.163000  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d683c0>
# 2369    active   2.151900  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d68580>
# 5212    active   1.517190  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d8e5e0>
# 3137    active   1.221849  <rdkit.Chem.rdchem.Mol object at 0x7ac8e0d75f50>
#
# [4711 rows x 5 columns]

# %%
mols2grid.display(activity_df, mol_col = 'Molecules', subset = ['molecule_chembl_id', 'class', 'pIC50'], transform={"pIC50": lambda x: f"{x:.2f}"})
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ## 5. Save DataSet<a name = 12></a>

# %%
activity_df.to_csv('bioactivity_final_cox2.csv', index=False)
